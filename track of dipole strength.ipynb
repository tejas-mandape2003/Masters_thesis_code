# %%
print("symmetric dipole tests")
print("28 jan initial dipole 3e-5")
print("29 jan initial dipole 6e-5")
print("29 jan 2 initial dipole 4e-5")
print("31 jan initial dipole 3.5e-5")
print("31 jan 2 initial dipole 3.5e-5, even grid")
print("All have their flux divided by 4")
print("1 feb initial dipole 3.5e-5, even grid, flux by 8")
print("12 march initial dipole 3.5e-5, even grid, flux by 4")
# Out:
# symmetric dipole tests
# 28 jan initial dipole 3e-5
# 29 jan initial dipole 6e-5
# 29 jan 2 initial dipole 4e-5
# 31 jan initial dipole 3.5e-5
# 31 jan 2 initial dipole 3.5e-5, even grid
# All have their flux divided by 4
# 1 feb initial dipole 3.5e-5, even grid, flux by 8
