# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

deg2rad = np.pi / 180.0
rad2deg = 180.0 / np.pi

R = 6.96e8
dt = 0.001
alpha = 6.048e13
dphi = 0.5*deg2rad
dtheta1_d = 0.5*3
dtheta2_d = 1
dtheta3_d = 0.5
tot_time = 365 * 11
N_steps = int(tot_time / dt)
save = 100
N_save = int(N_steps / save)+1
N_phi = int(2*np.pi/ dphi)
v_mer_max = 1.296e6
omega_max_deg = 13.38
omega_max = omega_max_deg*deg2rad

theta_1n = np.arange(5, 30, dtheta1_d)
theta_2n = np.arange(30, 60, dtheta2_d)
theta_3 = np.arange(60, 120, dtheta3_d)
theta_2s = np.arange(120, 150, dtheta2_d)
theta_1s = np.arange(150, 180 - 5, dtheta1_d)

print("theta_1n:", theta_1n.shape)
print("theta_2n:", theta_2n.shape)  
print("theta_3:", theta_3.shape)
print("theta_2s:", theta_2s.shape)
print("theta_1s:", theta_1s.shape)

N_theta = (len(theta_1n) + len(theta_2n) + len(theta_3) + len(theta_2s) + len(theta_1s))
theta_deg = np.concatenate((theta_1n, theta_2n, theta_3, theta_2s, theta_1s))

theta = theta_deg * deg2rad
dtheta1 = dtheta1_d * deg2rad
dtheta2 = dtheta2_d * deg2rad
dtheta3 = dtheta3_d * deg2rad

delta_x = R*np.min(np.sin(theta))*dphi
delta_y = R*dtheta3

stab_par = min((min(delta_x**2,delta_y**2))/(4*alpha), delta_y/v_mer_max, dphi/omega_max)
print(f"stab_par: {stab_par}")
assert dt <= stab_par, "Stability condition violated!!!!!!!!!!!"

phi = np.arange(0, 2 * np.pi, dphi)
phi_deg = phi * rad2deg
Phi, Theta = np.meshgrid(phi, theta)
Phi_grid, Theta_grid = np.meshgrid(phi, theta, indexing='ij')

Phi_deg1 = Phi * rad2deg
Theta_deg1 = Theta * rad2deg
Phi_deg2, Theta_deg2 = np.meshgrid(phi_deg, theta_deg, indexing="ij")

df = pd.read_csv("sunspots_input.dat", sep=r"\s+", header=None)
df.to_csv("input.csv", index=False)
df.columns = ['phase', 'latitude', 'tilt','radius in Mm','longitude', 'flux in Mx']
df['flux in Mx'] = df['flux in Mx'] * 1e16
df['radius in Mm'] = df['radius in Mm'] * 1e1 
bmr = df.to_numpy()
bmr_added = np.zeros(len(bmr), dtype=bool)
# Out:
# theta_1n: (17,)
# theta_2n: (30,)
# theta_3: (120,)
# theta_2s: (30,)
# theta_1s: (17,)
# stab_par: 0.0011583330978429725

# %%
print(df)
# Out:
#       phase  latitude      tilt  radius in Mm  longitude    flux in Mx
# 0         1       -22 -4.312603     74.942842         63  1.081406e+21
# 1         2        23  4.409528     64.524913        155  8.231345e+20
# 2         2       -26 -4.688294     40.260272        308  3.204567e+20
# 3         3        34  5.361269     44.602547        183  4.803827e+20
# 4         3       -21 -4.213449     15.085714        192  5.495406e+19
# ...     ...       ...       ...           ...        ...           ...
# 2992    152         2  1.300299     30.118318         50  2.336306e+20
# 2993    152        -4 -1.838900     38.672602          6  3.851901e+20
# 2994    152         5  2.055953     30.429389        259  2.384816e+20
# 2995    152        -3 -1.592534     16.764424        354  7.238450e+19
# 2996    152         9  2.758350     19.871604        205  1.017031e+20
#
# [2997 rows x 6 columns]

# %%
(4*deg2rad)**2
# Out:
# 0.004873878716587337

# %%
np.min(np.sin(theta))
# Out:
# np.float64(0.08715574274765817)

# %%
T = np.zeros((N_phi, N_theta), dtype=np.float32)

# %%
plt.figure(figsize=(10, 6))
plt.scatter(Phi_deg1, Theta_deg1, s=1, color='black')
plt.xlabel("φ (degrees)")
plt.ylabel("θ (degrees)")
plt.gca().invert_yaxis()
plt.title("Theta-Phi Grid (θ and φ in degrees)")
plt.xticks(np.arange(0, 361, 30))
plt.yticks(np.arange(0, 181, 30))
plt.grid(True)
plt.show()

# %%
N_phi, N_theta
# Out:
# (720, 214)

# %%
Phi.shape, Theta.shape, T.shape
# Out:
# ((214, 720), (214, 720), (720, 214))

# %%
dtheta_rad = np.zeros(N_theta)
dtheta_rad[:len(theta_1n)] = dtheta1
dtheta_rad[len(theta_1n):len(theta_1n) + len(theta_2n)] = dtheta2
dtheta_rad[len(theta_1n) + len(theta_2n):len(theta_1n) + len(theta_2n) + len(theta_3)] = dtheta3
dtheta_rad[len(theta_1n) + len(theta_2n) + len(theta_3):len(theta_1n) + len(theta_2n) + len(theta_3) + len(theta_2s)] = dtheta2
dtheta_rad[len(theta_1n) + len(theta_2n) + len(theta_3) + len(theta_2s):] = dtheta1

# %%
print(T.shape)
# Out:
# (720, 214)

# %%
B0 = 3e-5
initial_cap_deg = 25
initial_cap = initial_cap_deg * deg2rad
initial_profile = np.zeros(N_theta, dtype=np.float32)

north_initial = theta <= initial_cap
south_initial = theta >= (np.pi - initial_cap)

initial_profile[north_initial] =  B0 * np.cos(theta[north_initial])
initial_profile[south_initial] =  B0 * np.cos(theta[south_initial])

T[:, :] = initial_profile[None, :]

# %%
plt.figure(figsize=(8, 4))
plt.pcolormesh(Phi_deg1,Theta_deg1,-T.T,cmap="seismic",shading="nearest")
plt.colorbar(label="Magnetic field strength (Tesla)")
plt.xlabel("φ (degrees)")
plt.ylabel("θ (degrees)")
plt.ylim(theta_deg[0], theta_deg[-1])
xt = np.arange(0, 361, 30)
yt = np.arange(0, 181, 30)
plt.xticks(xt)
plt.yticks(yt)
for x in xt:
    plt.axvline(x, color="k", linewidth=0.5, alpha=0.4)

for y in yt:
    plt.axhline(y, color="k", linewidth=0.5, alpha=0.4)
plt.tight_layout()
plt.show()

# %%
omega = omega_max - (2.3 * (np.cos(theta))**2 - 1.62* (np.cos(theta))**4) * deg2rad

# %%
plt.plot(theta_deg, omega * rad2deg)
plt.xlabel("Theta (degrees)")
plt.ylabel(f"Omega (degrees/day)")
plt.show()

# %%
col = theta*rad2deg-90
v_mer = np.where(np.abs(col)<=75, v_mer_max * np.sin(np.pi * col / 75), 0)

# %%
plt.plot(col, v_mer)
plt.xlabel("colatitude (degrees)")
plt.ylabel("meridional velocity (metres/day)")
plt.show()

# %%
cot = 1/np.tan(theta)
sin2 = (np.sin(theta))**2
senin = 1/(np.sin(theta))
cos = np.cos(theta).astype(np.float32)
sin = np.sin(theta).astype(np.float32)
all_values = np.zeros((N_save, N_phi, N_theta),dtype=np.float32)
T = T.astype(np.float32)
all_values[0, :, :] = T
T_new = np.zeros_like(T).astype(np.float32)
T_new.shape
# Out:
# (720, 214)

# %%
north_cap = theta_deg<= 25
south_cap = theta_deg>= 155

element_area = (R**2) * sin * dtheta_rad * dphi

flux_north = []
flux_south = []
flux_total = []
time_days = []

# %%
#accum_bottom = np.zeros(N_phi)
#accum_top = np.zeros(N_phi)
save_idx = 0
all_values[save_idx, :, :]  = T
#all_values[save_idx, :, 0]  = accum_bottom
#all_values[save_idx, :, -1] = accum_top
save_idx += 1

# %%
C_phi_local = np.abs(omega) * dt / dphi
C_theta_local = np.abs(v_mer) * dt / (R * dtheta_rad)

print(f"Max C_phi = {np.max(C_phi_local):.4f}, Max C_theta = {np.max(C_theta_local):.4f}")

if np.max(C_phi_local) > 1.0 or np.max(C_theta_local) > 1.0:
    print("Warning: Local advection CFL > 1 — explicit scheme may become unstable.")
# Out:
# Max C_phi = 0.0268, Max C_theta = 0.0002

# %%
current_month = 0
next_bmr_index = 0

# %%
for n in range(1, N_steps + 1):
    t_days = n * dt
    month = int(t_days/30)

    if month > current_month:
        print(f"{month} month(s) start")
        current_month = month

    idx = next_bmr_index
    while idx < len(bmr) and not bmr_added[idx] and month >= bmr[idx, 0]:

        phase = bmr[idx, 0]
        lat_deg = bmr[idx, 1]
        tilt_deg = bmr[idx, 2]
        radius_Mm = bmr[idx, 3]
        lon_deg = bmr[idx, 4]
        flux = bmr[idx, 5]

        if month < phase:
            continue

        lat = lat_deg * deg2rad
        lon = lon_deg * deg2rad
        tilt = tilt_deg * deg2rad
        theta_c = np.pi/2.0 - lat

        R_cm = R * 100.0
        radius_cm = radius_Mm * 1e8

        ang_rad = radius_cm / R_cm # half angle of spot from centr
        sep_factor = 3.0
        d = sep_factor * ang_rad  # angular separation between spots

        dx = (d / 2.0) * np.cos(tilt)
        dy = (d / 2.0) * np.sin(tilt)
        dphi_off = dx / np.cos(lat)    # small angle correction for longitude
        dtheta_off = -dy
        sgn = 1 if lat > 0 else -1
        theta_lead  = theta_c + sgn * abs(dtheta_off)
        theta_trail = theta_c - sgn * abs(dtheta_off)

        phi_pos = lon + dphi_off
        phi_neg = lon - dphi_off

        if lat_deg > 0:      # Northern hemisphere
            leading_sign = +1
        else:                # Southern hemisphere
            leading_sign = -1

        flux_lead = leading_sign * flux
        flux_trail = -leading_sign * flux # assumed that the input flux is given for each spot(leading or following) 

        cap_area = 2.0 * np.pi * (R_cm**2) * (1.0 - np.cos(ang_rad)) #cm^2

        B0_lead = flux_lead / cap_area
        B0_trail = flux_trail / cap_area

        B0_lead_T = B0_lead * 1e-4
        B0_trail_T = B0_trail * 1e-4

        print("Inserting BMR idx=", idx, "phase=", phase, "month=", month)
        print(f" lat={lat_deg:.2f} deg, lon={lon_deg:.2f} deg, tilt={tilt_deg:.2f} deg")
        print(f" radius(Mm)={radius_Mm:.3f}, radius_cm={radius_cm:.3e}, ang_rad(deg)={(ang_rad*rad2deg):.4f}")
        print(f" flux(Mx)={flux:.3e}, cap_area(cm2)={cap_area:.3e}")
        print(f" B0_lead(T)={B0_lead_T:.3e}, B0_trail(T)={B0_trail_T:.3e}")

        cos_gamma_lead = (np.sin(Theta_grid) * np.sin(theta_lead) * np.cos(Phi_grid - phi_pos)
                         + np.cos(Theta_grid) * np.cos(theta_lead))
        #cos_gamma_lead = np.clip(cos_gamma_lead, -1.0, 1.0)
        #mask_lead = (cos_gamma_lead >= np.cos(ang_rad))
        #T[mask_lead] += B0_lead_T

        cos_gamma_trail = (np.sin(Theta_grid) * np.sin(theta_trail) * np.cos(Phi_grid - phi_neg) + np.cos(Theta_grid) * np.cos(theta_trail))
        #cos_gamma_trail = np.clip(cos_gamma_trail, -1.0, 1.0)
        #mask_trail = (cos_gamma_trail >= np.cos(ang_rad))
        #T[mask_trail] += B0_trail_T

        gamma_lead = np.arccos(cos_gamma_lead)
        gamma_trail = np.arccos(cos_gamma_trail)

        sigma = ang_rad/3 #assumed to have 1 percent of peak at gamma=alpha 

        B0_lead_T = flux_lead / (2.0 * np.pi * (R_cm**2) * sigma**2) * 1e-4 #after normalizing for flux 
        B0_trail_T = flux_trail / (2.0 * np.pi * (R_cm**2) * sigma**2) * 1e-4 #and small angle approximation

        T += B0_lead_T * np.exp(-0.5 * (gamma_lead / sigma)**2)
        T += B0_trail_T * np.exp(-0.5 * (gamma_trail / sigma)**2)        
        #nlead = np.count_nonzero(mask_lead)
        #ntrail = np.count_nonzero(mask_trail)
        #print(f" mask cells pos={nlead}, neg={ntrail}")

        bmr_added[idx] = True
        next_bmr_index += 1
        idx = next_bmr_index
    i_sl = slice(1, -1)
    j_sl = slice(1, -1)

    Tc   = T[i_sl, j_sl]                 
    T_ip = T[2:,  j_sl]                  
    T_im = T[:-2, j_sl]                 
    T_jp = T[i_sl, 2:]                   
    T_jm = T[i_sl, :-2]                  

    dth     = dtheta_rad[1:-1]         
    inv_dth = 1.0 / dth
    inv_dth2= inv_dth**2
    sin_i   = sin[1:-1]
    sin2_i  = sin2[1:-1]
    cos_i   = cos[1:-1]
    cot_i   = cot[1:-1]
    sin_c    = sin[1:-1]                   
    sin_ph   = sin[2:]                      
    sin_mh   = sin[:-2]                    
    omg_c    = omega[1:-1]                  
    v_ph     = 0.5*(v_mer[1:-1] + v_mer[2:])  
    v_mh     = 0.5*(v_mer[:-2]  + v_mer[1:-1]) 

    eps = 1e-1
    sin_i_safe  = np.maximum(sin_i,  eps)
    sin2_i_safe = np.maximum(sin2_i, eps**2)
    cot_i_safe = np.maximum(cot_i, eps)
    d2T_dtheta = (T_jp - 2.0 * Tc + T_jm) * inv_dth2
    cot_term   = cot_i_safe * ((Tc - T_jm) * inv_dth)
    d2T_dphi   = (T_ip - 2.0 * Tc + T_im) / (dphi**2)

    diffusion = (alpha / (R**2)) * dt * (d2T_dtheta + cot_term + (d2T_dphi / sin2_i_safe))   #diffusion term

    div_phi = omg_c * (Tc - T_im) / dphi   #-omega(theta) * del(B)/del(phi)

    vph_pos = v_ph >= 0
    vmh_pos = v_mh >= 0

    T_up_ph = np.where(vph_pos, Tc, T_jp)  
    Fth_ph  = v_ph * T_up_ph * sin_ph        

    T_up_mh = np.where(vmh_pos, T_jm, Tc) 
    Fth_mh  = v_mh * T_up_mh * sin_mh

    div_theta = (Fth_ph - Fth_mh) / dth  
    div_theta = div_theta / (R * np.maximum(sin_c,1e-3 ))   

    advection = -div_phi - div_theta

    T_new[i_sl, j_sl] = Tc + diffusion + dt * advection

    if np.any(np.isnan(T_new)) or np.any(np.isinf(T_new)):
        print(f"Numerical instability at step {n}")
        print(f"Max value in T_new: {np.nanmax(T_new)}, Min value: {np.nanmin(T_new)}")
        bad_indices = np.argwhere(~np.isfinite(T_new))
        print(f"Non-finite entries at indices (i,j): {bad_indices[:10]}")
        break

    T_new[0,   1:-1] = T_new[-2, 1:-1]
    T_new[-1,  1:-1] = T_new[1,  1:-1]

    #accum_bottom += T_new[:, 1]
    #accum_top    += T_new[:, -2]
    T_new[1:-1, 0]  = T_new[1:-1, 1]
    T_new[1:-1, -1] = T_new[1:-1, -2]
    T = T_new.copy()
    if (n % 100) == 0:
        all_values[save_idx, :, :]  = T
        #all_values[save_idx, :, 0]  = accum_bottom
        #all_values[save_idx, :, -1] = accum_top
        save_idx += 1
        flux_n = np.sum(T[:,north_cap] * element_area[north_cap][None,:])
        flux_s = np.sum(T[:,south_cap] * element_area[south_cap][None,:])
        flux_t = np.sum(T[:,:] * element_area[None,:])
        flux_north.append(flux_n)
        flux_south.append(flux_s)
        flux_total.append(flux_t)
        time_days.append(t_days)
# Out:
# 1 month(s) start
# Inserting BMR idx= 0 phase= 1.0 month= 1
#  lat=-22.00 deg, lon=63.00 deg, tilt=-4.31 deg
#  radius(Mm)=74.943, radius_cm=7.494e+09, ang_rad(deg)=6.1694
#  flux(Mx)=1.081e+21, cap_area(cm2)=1.763e+20
#  B0_lead(T)=-6.135e-04, B0_trail(T)=6.135e-04
# 2 month(s) start
# Inserting BMR idx= 1 phase= 2.0 month= 2
#  lat=23.00 deg, lon=155.00 deg, tilt=4.41 deg
#  radius(Mm)=64.525, radius_cm=6.452e+09, ang_rad(deg)=5.3118
#  flux(Mx)=8.231e+20, cap_area(cm2)=1.307e+20
#  B0_lead(T)=6.298e-04, B0_trail(T)=-6.298e-04
# Inserting BMR idx= 2 phase= 2.0 month= 2
#  lat=-26.00 deg, lon=308.00 deg, tilt=-4.69 deg
#  radius(Mm)=40.260, radius_cm=4.026e+09, ang_rad(deg)=3.3143
#  flux(Mx)=3.205e+20, cap_area(cm2)=5.091e+19
#  B0_lead(T)=-6.295e-04, B0_trail(T)=6.295e-04
# 3 month(s) start
# Inserting BMR idx= 3 phase= 3.0 month= 3
#  lat=34.00 deg, lon=183.00 deg, tilt=5.36 deg
#  radius(Mm)=44.603, radius_cm=4.460e+09, ang_rad(deg)=3.6717
#  flux(Mx)=4.804e+20, cap_area(cm2)=6.248e+19
#  B0_lead(T)=7.689e-04, B0_trail(T)=-7.689e-04
# Inserting BMR idx= 4 phase= 3.0 month= 3
#  lat=-21.00 deg, lon=192.00 deg, tilt=-4.21 deg
#  radius(Mm)=15.086, radius_cm=1.509e+09, ang_rad(deg)=1.2419
#  flux(Mx)=5.495e+19, cap_area(cm2)=7.149e+18
#  B0_lead(T)=-7.687e-04, B0_trail(T)=7.687e-04
# Inserting BMR idx= 5 phase= 3.0 month= 3
#  lat=34.00 deg, lon=52.00 deg, tilt=5.36 deg
#  radius(Mm)=15.625, radius_cm=1.563e+09, ang_rad(deg)=1.2863
#  flux(Mx)=5.896e+19, cap_area(cm2)=7.670e+18
#  B0_lead(T)=7.687e-04, B0_trail(T)=-7.687e-04
# Inserting BMR idx= 6 phase= 3.0 month= 3
#  lat=-34.00 deg, lon=279.00 deg, tilt=-5.36 deg
#  radius(Mm)=53.819, radius_cm=5.382e+09, ang_rad(deg)=4.4305
#  flux(Mx)=6.994e+20, cap_area(cm2)=9.095e+19
#  B0_lead(T)=-7.690e-04, B0_trail(T)=7.690e-04
# Inserting BMR idx= 7 phase= 3.0 month= 3
#  lat=38.00 deg, lon=209.00 deg, tilt=5.67 deg
#  radius(Mm)=76.152, radius_cm=7.615e+09, ang_rad(deg)=6.2689
#  flux(Mx)=1.400e+21, cap_area(cm2)=1.820e+20
#  B0_lead(T)=7.694e-04, B0_trail(T)=-7.694e-04
# Inserting BMR idx= 8 phase= 3.0 month= 3
#  lat=-24.00 deg, lon=120.00 deg, tilt=-4.50 deg
#  radius(Mm)=12.689, radius_cm=1.269e+09, ang_rad(deg)=1.0446
#  flux(Mx)=3.888e+19, cap_area(cm2)=5.058e+18
#  B0_lead(T)=-7.687e-04, B0_trail(T)=7.687e-04
# Inserting BMR idx= 9 phase= 3.0 month= 3
#  lat=30.00 deg, lon=353.00 deg, tilt=5.04 deg
#  radius(Mm)=59.548, radius_cm=5.955e+09, ang_rad(deg)=4.9021
#  flux(Mx)=8.562e+20, cap_area(cm2)=1.113e+20
#  B0_lead(T)=7.691e-04, B0_trail(T)=-7.691e-04
# Inserting BMR idx= 10 phase= 3.0 month= 3
#  lat=-28.00 deg, lon=349.00 deg, tilt=-4.87 deg
#  radius(Mm)=40.140, radius_cm=4.014e+09, ang_rad(deg)=3.3043
#  flux(Mx)=3.891e+20, cap_area(cm2)=5.060e+19
#  B0_lead(T)=-7.688e-04, B0_trail(T)=7.688e-04
# 4 month(s) start
# Inserting BMR idx= 11 phase= 4.0 month= 4
#  lat=23.00 deg, lon=202.00 deg, tilt=4.41 deg
#  radius(Mm)=45.637, radius_cm=4.564e+09, ang_rad(deg)=3.7569
#  flux(Mx)=4.836e+20, cap_area(cm2)=6.541e+19
#  B0_lead(T)=7.393e-04, B0_trail(T)=-7.393e-04
# Inserting BMR idx= 12 phase= 4.0 month= 4
#  lat=-18.00 deg, lon=89.00 deg, tilt=-3.90 deg
#  radius(Mm)=38.139, radius_cm=3.814e+09, ang_rad(deg)=3.1396
#  flux(Mx)=3.377e+20, cap_area(cm2)=4.568e+19
#  B0_lead(T)=-7.392e-04, B0_trail(T)=7.392e-04
# Inserting BMR idx= 13 phase= 4.0 month= 4
#  lat=41.00 deg, lon=161.00 deg, tilt=5.89 deg
#  radius(Mm)=15.532, radius_cm=1.553e+09, ang_rad(deg)=1.2786
#  flux(Mx)=5.601e+19, cap_area(cm2)=7.579e+18
#  B0_lead(T)=7.391e-04, B0_trail(T)=-7.391e-04
# Inserting BMR idx= 14 phase= 4.0 month= 4
#  lat=-29.00 deg, lon=171.00 deg, tilt=-4.95 deg
#  radius(Mm)=28.781, radius_cm=2.878e+09, ang_rad(deg)=2.3693
#  flux(Mx)=1.923e+20, cap_area(cm2)=2.602e+19
#  B0_lead(T)=-7.391e-04, B0_trail(T)=7.391e-04
# Inserting BMR idx= 15 phase= 4.0 month= 4
#  lat=21.00 deg, lon=80.00 deg, tilt=4.21 deg
#  radius(Mm)=35.703, radius_cm=3.570e+09, ang_rad(deg)=2.9391
#  flux(Mx)=2.960e+20, cap_area(cm2)=4.004e+19
#  B0_lead(T)=7.392e-04, B0_trail(T)=-7.392e-04
# Inserting BMR idx= 16 phase= 4.0 month= 4
#  lat=-42.00 deg, lon=95.00 deg, tilt=-5.96 deg
#  radius(Mm)=27.307, radius_cm=2.731e+09, ang_rad(deg)=2.2479
#  flux(Mx)=1.731e+20, cap_area(cm2)=2.342e+19
#  B0_lead(T)=-7.391e-04, B0_trail(T)=7.391e-04
# 5 month(s) start
# Inserting BMR idx= 17 phase= 5.0 month= 5
#  lat=28.00 deg, lon=202.00 deg, tilt=4.87 deg
#  radius(Mm)=36.051, radius_cm=3.605e+09, ang_rad(deg)=2.9678
#  flux(Mx)=3.054e+20, cap_area(cm2)=4.082e+19
#  B0_lead(T)=7.481e-04, B0_trail(T)=-7.481e-04
# Inserting BMR idx= 18 phase= 5.0 month= 5
#  lat=-21.00 deg, lon=30.00 deg, tilt=-4.21 deg
#  radius(Mm)=70.917, radius_cm=7.092e+09, ang_rad(deg)=5.8380
#  flux(Mx)=1.182e+21, cap_area(cm2)=1.579e+20
#  B0_lead(T)=-7.486e-04, B0_trail(T)=7.486e-04
# Inserting BMR idx= 19 phase= 5.0 month= 5
#  lat=41.00 deg, lon=66.00 deg, tilt=5.89 deg
#  radius(Mm)=22.180, radius_cm=2.218e+09, ang_rad(deg)=1.8259
#  flux(Mx)=1.156e+20, cap_area(cm2)=1.545e+19
#  B0_lead(T)=7.480e-04, B0_trail(T)=-7.480e-04
# Inserting BMR idx= 20 phase= 5.0 month= 5
#  lat=-20.00 deg, lon=3.00 deg, tilt=-4.11 deg
#  radius(Mm)=43.761, radius_cm=4.376e+09, ang_rad(deg)=3.6025
#  flux(Mx)=4.500e+20, cap_area(cm2)=6.014e+19
#  B0_lead(T)=-7.482e-04, B0_trail(T)=7.482e-04
# Inserting BMR idx= 21 phase= 5.0 month= 5
#  lat=22.00 deg, lon=285.00 deg, tilt=4.31 deg
#  radius(Mm)=16.718, radius_cm=1.672e+09, ang_rad(deg)=1.3763
#  flux(Mx)=6.567e+19, cap_area(cm2)=8.780e+18
#  B0_lead(T)=7.480e-04, B0_trail(T)=-7.480e-04
# Inserting BMR idx= 22 phase= 5.0 month= 5
#  lat=-19.00 deg, lon=343.00 deg, tilt=-4.01 deg
#  radius(Mm)=15.193, radius_cm=1.519e+09, ang_rad(deg)=1.2508
#  flux(Mx)=5.424e+19, cap_area(cm2)=7.252e+18
#  B0_lead(T)=-7.479e-04, B0_trail(T)=7.479e-04
# 6 month(s) start
# Inserting BMR idx= 23 phase= 6.0 month= 6
#  lat=27.00 deg, lon=22.00 deg, tilt=4.78 deg
#  radius(Mm)=76.852, radius_cm=7.685e+09, ang_rad(deg)=6.3266
#  flux(Mx)=1.260e+21, cap_area(cm2)=1.854e+20
#  B0_lead(T)=6.799e-04, B0_trail(T)=-6.799e-04
# Inserting BMR idx= 24 phase= 6.0 month= 6
#  lat=-24.00 deg, lon=260.00 deg, tilt=-4.50 deg
#  radius(Mm)=28.232, radius_cm=2.823e+09, ang_rad(deg)=2.3241
#  flux(Mx)=1.701e+20, cap_area(cm2)=2.504e+19
#  B0_lead(T)=-6.793e-04, B0_trail(T)=6.793e-04
# Inserting BMR idx= 25 phase= 6.0 month= 6
#  lat=21.00 deg, lon=148.00 deg, tilt=4.21 deg
#  radius(Mm)=37.235, radius_cm=3.724e+09, ang_rad(deg)=3.0653
#  flux(Mx)=2.959e+20, cap_area(cm2)=4.355e+19
#  B0_lead(T)=6.794e-04, B0_trail(T)=-6.794e-04
# Inserting BMR idx= 26 phase= 6.0 month= 6
#  lat=-38.00 deg, lon=271.00 deg, tilt=-5.67 deg
#  radius(Mm)=23.609, radius_cm=2.361e+09, ang_rad(deg)=1.9436
#  flux(Mx)=1.189e+20, cap_area(cm2)=1.751e+19
#  B0_lead(T)=-6.793e-04, B0_trail(T)=6.793e-04
# 7 month(s) start
# Inserting BMR idx= 27 phase= 7.0 month= 7
#  lat=28.00 deg, lon=306.00 deg, tilt=4.87 deg
#  radius(Mm)=52.770, radius_cm=5.277e+09, ang_rad(deg)=4.3441
#  flux(Mx)=5.898e+20, cap_area(cm2)=8.744e+19
#  B0_lead(T)=6.745e-04, B0_trail(T)=-6.745e-04
# Inserting BMR idx= 28 phase= 7.0 month= 7
#  lat=-26.00 deg, lon=222.00 deg, tilt=-4.69 deg
#  radius(Mm)=79.155, radius_cm=7.916e+09, ang_rad(deg)=6.5162
#  flux(Mx)=1.327e+21, cap_area(cm2)=1.966e+20
#  B0_lead(T)=-6.749e-04, B0_trail(T)=6.749e-04
# Inserting BMR idx= 29 phase= 7.0 month= 7
#  lat=28.00 deg, lon=79.00 deg, tilt=4.87 deg
#  radius(Mm)=23.809, radius_cm=2.381e+09, ang_rad(deg)=1.9600
#  flux(Mx)=1.201e+20, cap_area(cm2)=1.781e+19
#  B0_lead(T)=6.742e-04, B0_trail(T)=-6.742e-04
# 8 month(s) start
# Inserting BMR idx= 30 phase= 8.0 month= 8
#  lat=-38.00 deg, lon=4.00 deg, tilt=-5.67 deg
#  radius(Mm)=50.243, radius_cm=5.024e+09, ang_rad(deg)=4.1361
#  flux(Mx)=6.196e+20, cap_area(cm2)=7.927e+19
#  B0_lead(T)=-7.817e-04, B0_trail(T)=7.817e-04
# Inserting BMR idx= 31 phase= 8.0 month= 8
#  lat=41.00 deg, lon=352.00 deg, tilt=5.89 deg
#  radius(Mm)=41.787, radius_cm=4.179e+09, ang_rad(deg)=3.4400
#  flux(Mx)=4.286e+20, cap_area(cm2)=5.484e+19
#  B0_lead(T)=7.816e-04, B0_trail(T)=-7.816e-04
# Inserting BMR idx= 32 phase= 8.0 month= 8
#  lat=-33.00 deg, lon=346.00 deg, tilt=-5.28 deg
#  radius(Mm)=21.897, radius_cm=2.190e+09, ang_rad(deg)=1.8026
#  flux(Mx)=1.177e+20, cap_area(cm2)=1.506e+19
#  B0_lead(T)=-7.814e-04, B0_trail(T)=7.814e-04
# Inserting BMR idx= 33 phase= 8.0 month= 8
#  lat=22.00 deg, lon=195.00 deg, tilt=4.31 deg
#  radius(Mm)=35.693, radius_cm=3.569e+09, ang_rad(deg)=2.9383
#  flux(Mx)=3.127e+20, cap_area(cm2)=4.002e+19
#  B0_lead(T)=7.815e-04, B0_trail(T)=-7.815e-04
# Inserting BMR idx= 34 phase= 8.0 month= 8
#  lat=-34.00 deg, lon=198.00 deg, tilt=-5.36 deg
#  radius(Mm)=10.095, radius_cm=1.009e+09, ang_rad(deg)=0.8310
#  flux(Mx)=2.501e+19, cap_area(cm2)=3.201e+18
#  B0_lead(T)=-7.813e-04, B0_trail(T)=7.813e-04
# Inserting BMR idx= 35 phase= 8.0 month= 8
#  lat=40.00 deg, lon=107.00 deg, tilt=5.82 deg
#  radius(Mm)=63.363, radius_cm=6.336e+09, ang_rad(deg)=5.2161
#  flux(Mx)=9.855e+20, cap_area(cm2)=1.260e+20
#  B0_lead(T)=7.819e-04, B0_trail(T)=-7.819e-04
# Inserting BMR idx= 36 phase= 8.0 month= 8
#  lat=-23.00 deg, lon=122.00 deg, tilt=-4.41 deg
#  radius(Mm)=34.120, radius_cm=3.412e+09, ang_rad(deg)=2.8088
#  flux(Mx)=2.858e+20, cap_area(cm2)=3.657e+19
#  B0_lead(T)=-7.815e-04, B0_trail(T)=7.815e-04
# Inserting BMR idx= 37 phase= 8.0 month= 8
#  lat=39.00 deg, lon=180.00 deg, tilt=5.74 deg
#  radius(Mm)=16.828, radius_cm=1.683e+09, ang_rad(deg)=1.3853
#  flux(Mx)=6.951e+19, cap_area(cm2)=8.896e+18
#  B0_lead(T)=7.814e-04, B0_trail(T)=-7.814e-04
# Inserting BMR idx= 38 phase= 8.0 month= 8
#  lat=-29.00 deg, lon=335.00 deg, tilt=-4.95 deg
#  radius(Mm)=42.535, radius_cm=4.254e+09, ang_rad(deg)=3.5016
#  flux(Mx)=4.441e+20, cap_area(cm2)=5.682e+19
#  B0_lead(T)=-7.816e-04, B0_trail(T)=7.816e-04
# 9 month(s) start
# Inserting BMR idx= 39 phase= 9.0 month= 9
#  lat=30.00 deg, lon=330.00 deg, tilt=5.04 deg
#  radius(Mm)=58.442, radius_cm=5.844e+09, ang_rad(deg)=4.8110
#  flux(Mx)=9.402e+20, cap_area(cm2)=1.072e+20
#  B0_lead(T)=8.768e-04, B0_trail(T)=-8.768e-04
# Inserting BMR idx= 40 phase= 9.0 month= 9
#  lat=-32.00 deg, lon=248.00 deg, tilt=-5.20 deg
#  radius(Mm)=77.406, radius_cm=7.741e+09, ang_rad(deg)=6.3722
#  flux(Mx)=1.649e+21, cap_area(cm2)=1.880e+20
#  B0_lead(T)=-8.772e-04, B0_trail(T)=8.772e-04
# Inserting BMR idx= 41 phase= 9.0 month= 9
#  lat=38.00 deg, lon=52.00 deg, tilt=5.67 deg
#  radius(Mm)=25.430, radius_cm=2.543e+09, ang_rad(deg)=2.0934
#  flux(Mx)=1.780e+20, cap_area(cm2)=2.031e+19
#  B0_lead(T)=8.764e-04, B0_trail(T)=-8.764e-04
# Inserting BMR idx= 42 phase= 9.0 month= 9
#  lat=-36.00 deg, lon=52.00 deg, tilt=-5.52 deg
#  radius(Mm)=55.265, radius_cm=5.527e+09, ang_rad(deg)=4.5495
#  flux(Mx)=8.408e+20, cap_area(cm2)=9.590e+19
#  B0_lead(T)=-8.767e-04, B0_trail(T)=8.767e-04
# Inserting BMR idx= 43 phase= 9.0 month= 9
#  lat=29.00 deg, lon=137.00 deg, tilt=4.95 deg
#  radius(Mm)=22.382, radius_cm=2.238e+09, ang_rad(deg)=1.8425
#  flux(Mx)=1.379e+20, cap_area(cm2)=1.574e+19
#  B0_lead(T)=8.763e-04, B0_trail(T)=-8.763e-04
# Inserting BMR idx= 44 phase= 9.0 month= 9
#  lat=-41.00 deg, lon=359.00 deg, tilt=-5.89 deg
#  radius(Mm)=73.298, radius_cm=7.330e+09, ang_rad(deg)=6.0340
#  flux(Mx)=1.479e+21, cap_area(cm2)=1.686e+20
#  B0_lead(T)=-8.771e-04, B0_trail(T)=8.771e-04
# Inserting BMR idx= 45 phase= 9.0 month= 9
#  lat=33.00 deg, lon=266.00 deg, tilt=5.28 deg
#  radius(Mm)=66.784, radius_cm=6.678e+09, ang_rad(deg)=5.4978
#  flux(Mx)=1.228e+21, cap_area(cm2)=1.400e+20
#  B0_lead(T)=8.769e-04, B0_trail(T)=-8.769e-04
# Inserting BMR idx= 46 phase= 9.0 month= 9
#  lat=-28.00 deg, lon=239.00 deg, tilt=-4.87 deg
#  radius(Mm)=69.385, radius_cm=6.938e+09, ang_rad(deg)=5.7118
#  flux(Mx)=1.325e+21, cap_area(cm2)=1.511e+20
#  B0_lead(T)=-8.770e-04, B0_trail(T)=8.770e-04
# Inserting BMR idx= 47 phase= 9.0 month= 9
#  lat=38.00 deg, lon=327.00 deg, tilt=5.67 deg
#  radius(Mm)=27.230, radius_cm=2.723e+09, ang_rad(deg)=2.2416
#  flux(Mx)=2.041e+20, cap_area(cm2)=2.329e+19
#  B0_lead(T)=8.764e-04, B0_trail(T)=-8.764e-04
# 10 month(s) start
# Inserting BMR idx= 48 phase= 10.0 month= 10
#  lat=-34.00 deg, lon=287.00 deg, tilt=-5.36 deg
#  radius(Mm)=10.719, radius_cm=1.072e+09, ang_rad(deg)=0.8824
#  flux(Mx)=3.225e+19, cap_area(cm2)=3.609e+18
#  B0_lead(T)=-8.934e-04, B0_trail(T)=8.934e-04
# Inserting BMR idx= 49 phase= 10.0 month= 10
#  lat=35.00 deg, lon=67.00 deg, tilt=5.44 deg
#  radius(Mm)=49.748, radius_cm=4.975e+09, ang_rad(deg)=4.0953
#  flux(Mx)=6.946e+20, cap_area(cm2)=7.772e+19
#  B0_lead(T)=8.937e-04, B0_trail(T)=-8.937e-04
# Inserting BMR idx= 50 phase= 10.0 month= 10
#  lat=-42.00 deg, lon=267.00 deg, tilt=-5.96 deg
#  radius(Mm)=42.067, radius_cm=4.207e+09, ang_rad(deg)=3.4630
#  flux(Mx)=4.967e+20, cap_area(cm2)=5.558e+19
#  B0_lead(T)=-8.936e-04, B0_trail(T)=8.936e-04
# Inserting BMR idx= 51 phase= 10.0 month= 10
#  lat=41.00 deg, lon=221.00 deg, tilt=5.89 deg
#  radius(Mm)=28.532, radius_cm=2.853e+09, ang_rad(deg)=2.3488
#  flux(Mx)=2.285e+20, cap_area(cm2)=2.557e+19
#  B0_lead(T)=8.935e-04, B0_trail(T)=-8.935e-04
# Inserting BMR idx= 52 phase= 10.0 month= 10
#  lat=-39.00 deg, lon=259.00 deg, tilt=-5.74 deg
#  radius(Mm)=45.879, radius_cm=4.588e+09, ang_rad(deg)=3.7768
#  flux(Mx)=5.907e+20, cap_area(cm2)=6.610e+19
#  B0_lead(T)=-8.937e-04, B0_trail(T)=8.937e-04
# Inserting BMR idx= 53 phase= 10.0 month= 10
#  lat=24.00 deg, lon=178.00 deg, tilt=4.50 deg
#  radius(Mm)=41.253, radius_cm=4.125e+09, ang_rad(deg)=3.3960
#  flux(Mx)=4.776e+20, cap_area(cm2)=5.345e+19
#  B0_lead(T)=8.936e-04, B0_trail(T)=-8.936e-04
# Inserting BMR idx= 54 phase= 10.0 month= 10
#  lat=-30.00 deg, lon=48.00 deg, tilt=-5.04 deg
#  radius(Mm)=72.957, radius_cm=7.296e+09, ang_rad(deg)=6.0060
#  flux(Mx)=1.494e+21, cap_area(cm2)=1.671e+20
#  B0_lead(T)=-8.942e-04, B0_trail(T)=8.942e-04
# Inserting BMR idx= 55 phase= 10.0 month= 10
#  lat=30.00 deg, lon=231.00 deg, tilt=5.04 deg
#  radius(Mm)=13.704, radius_cm=1.370e+09, ang_rad(deg)=1.1281
#  flux(Mx)=5.271e+19, cap_area(cm2)=5.900e+18
#  B0_lead(T)=8.934e-04, B0_trail(T)=-8.934e-04
# Inserting BMR idx= 56 phase= 10.0 month= 10
#  lat=-19.00 deg, lon=82.00 deg, tilt=-4.01 deg
#  radius(Mm)=36.001, radius_cm=3.600e+09, ang_rad(deg)=2.9637
#  flux(Mx)=3.638e+20, cap_area(cm2)=4.071e+19
#  B0_lead(T)=-8.936e-04, B0_trail(T)=8.936e-04
# Inserting BMR idx= 57 phase= 10.0 month= 10
#  lat=27.00 deg, lon=324.00 deg, tilt=4.78 deg
#  radius(Mm)=73.963, radius_cm=7.396e+09, ang_rad(deg)=6.0888
#  flux(Mx)=1.535e+21, cap_area(cm2)=1.717e+20
#  B0_lead(T)=8.942e-04, B0_trail(T)=-8.942e-04
# Inserting BMR idx= 58 phase= 10.0 month= 10
#  lat=-31.00 deg, lon=317.00 deg, tilt=-5.12 deg
#  radius(Mm)=46.916, radius_cm=4.692e+09, ang_rad(deg)=3.8622
#  flux(Mx)=6.178e+20, cap_area(cm2)=6.912e+19
#  B0_lead(T)=-8.937e-04, B0_trail(T)=8.937e-04
# Inserting BMR idx= 59 phase= 10.0 month= 10
#  lat=39.00 deg, lon=315.00 deg, tilt=5.74 deg
#  radius(Mm)=54.148, radius_cm=5.415e+09, ang_rad(deg)=4.4576
#  flux(Mx)=8.229e+20, cap_area(cm2)=9.207e+19
#  B0_lead(T)=8.938e-04, B0_trail(T)=-8.938e-04
# 11 month(s) start
# Inserting BMR idx= 60 phase= 11.0 month= 11
#  lat=-28.00 deg, lon=20.00 deg, tilt=-4.87 deg
#  radius(Mm)=12.361, radius_cm=1.236e+09, ang_rad(deg)=1.0176
#  flux(Mx)=3.576e+19, cap_area(cm2)=4.800e+18
#  B0_lead(T)=-7.450e-04, B0_trail(T)=7.450e-04
# Inserting BMR idx= 61 phase= 11.0 month= 11
#  lat=36.00 deg, lon=214.00 deg, tilt=5.52 deg
#  radius(Mm)=78.305, radius_cm=7.831e+09, ang_rad(deg)=6.4462
#  flux(Mx)=1.435e+21, cap_area(cm2)=1.924e+20
#  B0_lead(T)=7.457e-04, B0_trail(T)=-7.457e-04
# Inserting BMR idx= 62 phase= 11.0 month= 11
#  lat=-40.00 deg, lon=273.00 deg, tilt=-5.82 deg
#  radius(Mm)=14.537, radius_cm=1.454e+09, ang_rad(deg)=1.1967
#  flux(Mx)=4.946e+19, cap_area(cm2)=6.639e+18
#  B0_lead(T)=-7.450e-04, B0_trail(T)=7.450e-04
# Inserting BMR idx= 63 phase= 11.0 month= 11
#  lat=36.00 deg, lon=40.00 deg, tilt=5.52 deg
#  radius(Mm)=34.742, radius_cm=3.474e+09, ang_rad(deg)=2.8600
#  flux(Mx)=2.825e+20, cap_area(cm2)=3.791e+19
#  B0_lead(T)=7.451e-04, B0_trail(T)=-7.451e-04
# Inserting BMR idx= 64 phase= 11.0 month= 11
#  lat=-38.00 deg, lon=93.00 deg, tilt=-5.67 deg
#  radius(Mm)=47.909, radius_cm=4.791e+09, ang_rad(deg)=3.9439
#  flux(Mx)=5.372e+20, cap_area(cm2)=7.208e+19
#  B0_lead(T)=-7.452e-04, B0_trail(T)=7.452e-04
# Inserting BMR idx= 65 phase= 11.0 month= 11
#  lat=35.00 deg, lon=340.00 deg, tilt=5.44 deg
#  radius(Mm)=69.352, radius_cm=6.935e+09, ang_rad(deg)=5.7092
#  flux(Mx)=1.126e+21, cap_area(cm2)=1.510e+20
#  B0_lead(T)=7.456e-04, B0_trail(T)=-7.456e-04
# Inserting BMR idx= 66 phase= 11.0 month= 11
#  lat=-36.00 deg, lon=216.00 deg, tilt=-5.52 deg
#  radius(Mm)=41.458, radius_cm=4.146e+09, ang_rad(deg)=3.4128
#  flux(Mx)=4.022e+20, cap_area(cm2)=5.398e+19
#  B0_lead(T)=-7.452e-04, B0_trail(T)=7.452e-04
# 12 month(s) start
# Inserting BMR idx= 67 phase= 12.0 month= 12
#  lat=16.00 deg, lon=80.00 deg, tilt=3.68 deg
#  radius(Mm)=77.278, radius_cm=7.728e+09, ang_rad(deg)=6.3616
#  flux(Mx)=1.549e+21, cap_area(cm2)=1.874e+20
#  B0_lead(T)=8.262e-04, B0_trail(T)=-8.262e-04
# Inserting BMR idx= 68 phase= 12.0 month= 12
#  lat=-40.00 deg, lon=145.00 deg, tilt=-5.82 deg
#  radius(Mm)=41.932, radius_cm=4.193e+09, ang_rad(deg)=3.4519
#  flux(Mx)=4.559e+20, cap_area(cm2)=5.522e+19
#  B0_lead(T)=-8.256e-04, B0_trail(T)=8.256e-04
# Inserting BMR idx= 69 phase= 12.0 month= 12
#  lat=30.00 deg, lon=350.00 deg, tilt=5.04 deg
#  radius(Mm)=70.079, radius_cm=7.008e+09, ang_rad(deg)=5.7690
#  flux(Mx)=1.273e+21, cap_area(cm2)=1.542e+20
#  B0_lead(T)=8.261e-04, B0_trail(T)=-8.261e-04
# Inserting BMR idx= 70 phase= 12.0 month= 12
#  lat=-28.00 deg, lon=169.00 deg, tilt=-4.87 deg
#  radius(Mm)=11.299, radius_cm=1.130e+09, ang_rad(deg)=0.9301
#  flux(Mx)=3.310e+19, cap_area(cm2)=4.011e+18
#  B0_lead(T)=-8.254e-04, B0_trail(T)=8.254e-04
# Inserting BMR idx= 71 phase= 12.0 month= 12
#  lat=17.00 deg, lon=358.00 deg, tilt=3.79 deg
#  radius(Mm)=70.745, radius_cm=7.074e+09, ang_rad(deg)=5.8238
#  flux(Mx)=1.298e+21, cap_area(cm2)=1.571e+20
#  B0_lead(T)=8.261e-04, B0_trail(T)=-8.261e-04
# Inserting BMR idx= 72 phase= 12.0 month= 12
#  lat=-35.00 deg, lon=284.00 deg, tilt=-5.44 deg
#  radius(Mm)=69.296, radius_cm=6.930e+09, ang_rad(deg)=5.7046
#  flux(Mx)=1.245e+21, cap_area(cm2)=1.507e+20
#  B0_lead(T)=-8.261e-04, B0_trail(T)=8.261e-04
# Inserting BMR idx= 73 phase= 12.0 month= 12
#  lat=29.00 deg, lon=206.00 deg, tilt=4.95 deg
#  radius(Mm)=10.463, radius_cm=1.046e+09, ang_rad(deg)=0.8613
#  flux(Mx)=2.839e+19, cap_area(cm2)=3.439e+18
#  B0_lead(T)=8.254e-04, B0_trail(T)=-8.254e-04
# Inserting BMR idx= 74 phase= 12.0 month= 12
#  lat=-34.00 deg, lon=218.00 deg, tilt=-5.36 deg
#  radius(Mm)=17.328, radius_cm=1.733e+09, ang_rad(deg)=1.4264
#  flux(Mx)=7.785e+19, cap_area(cm2)=9.432e+18
#  B0_lead(T)=-8.254e-04, B0_trail(T)=8.254e-04
# Inserting BMR idx= 75 phase= 12.0 month= 12
#  lat=35.00 deg, lon=334.00 deg, tilt=5.44 deg
#  radius(Mm)=34.740, radius_cm=3.474e+09, ang_rad(deg)=2.8598
#  flux(Mx)=3.129e+20, cap_area(cm2)=3.791e+19
#  B0_lead(T)=8.256e-04, B0_trail(T)=-8.256e-04
# 13 month(s) start
# Inserting BMR idx= 76 phase= 13.0 month= 13
#  lat=-20.00 deg, lon=247.00 deg, tilt=-4.11 deg
#  radius(Mm)=10.569, radius_cm=1.057e+09, ang_rad(deg)=0.8701
#  flux(Mx)=2.991e+19, cap_area(cm2)=3.509e+18
#  B0_lead(T)=-8.525e-04, B0_trail(T)=8.525e-04
# Inserting BMR idx= 77 phase= 13.0 month= 13
#  lat=40.00 deg, lon=136.00 deg, tilt=5.82 deg
#  radius(Mm)=53.880, radius_cm=5.388e+09, ang_rad(deg)=4.4355
#  flux(Mx)=7.775e+20, cap_area(cm2)=9.116e+19
#  B0_lead(T)=8.529e-04, B0_trail(T)=-8.529e-04
# Inserting BMR idx= 78 phase= 13.0 month= 13
#  lat=-39.00 deg, lon=190.00 deg, tilt=-5.74 deg
#  radius(Mm)=56.021, radius_cm=5.602e+09, ang_rad(deg)=4.6118
#  flux(Mx)=8.405e+20, cap_area(cm2)=9.854e+19
#  B0_lead(T)=-8.529e-04, B0_trail(T)=8.529e-04
# Inserting BMR idx= 79 phase= 13.0 month= 13
#  lat=39.00 deg, lon=326.00 deg, tilt=5.74 deg
#  radius(Mm)=62.085, radius_cm=6.209e+09, ang_rad(deg)=5.1109
#  flux(Mx)=1.032e+21, cap_area(cm2)=1.210e+20
#  B0_lead(T)=8.530e-04, B0_trail(T)=-8.530e-04
# Inserting BMR idx= 80 phase= 13.0 month= 13
#  lat=-30.00 deg, lon=349.00 deg, tilt=-5.04 deg
#  radius(Mm)=54.770, radius_cm=5.477e+09, ang_rad(deg)=4.5087
#  flux(Mx)=8.033e+20, cap_area(cm2)=9.419e+19
#  B0_lead(T)=-8.529e-04, B0_trail(T)=8.529e-04
# Inserting BMR idx= 81 phase= 13.0 month= 13
#  lat=18.00 deg, lon=169.00 deg, tilt=3.90 deg
#  radius(Mm)=27.991, radius_cm=2.799e+09, ang_rad(deg)=2.3042
#  flux(Mx)=2.098e+20, cap_area(cm2)=2.461e+19
#  B0_lead(T)=8.526e-04, B0_trail(T)=-8.526e-04
# Inserting BMR idx= 82 phase= 13.0 month= 13
#  lat=-27.00 deg, lon=220.00 deg, tilt=-4.78 deg
#  radius(Mm)=51.905, radius_cm=5.191e+09, ang_rad(deg)=4.2729
#  flux(Mx)=7.215e+20, cap_area(cm2)=8.460e+19
#  B0_lead(T)=-8.528e-04, B0_trail(T)=8.528e-04
# Inserting BMR idx= 83 phase= 13.0 month= 13
#  lat=42.00 deg, lon=17.00 deg, tilt=5.96 deg
#  radius(Mm)=43.969, radius_cm=4.397e+09, ang_rad(deg)=3.6196
#  flux(Mx)=5.177e+20, cap_area(cm2)=6.072e+19
#  B0_lead(T)=8.527e-04, B0_trail(T)=-8.527e-04
# Inserting BMR idx= 84 phase= 13.0 month= 13
#  lat=-21.00 deg, lon=244.00 deg, tilt=-4.21 deg
#  radius(Mm)=12.937, radius_cm=1.294e+09, ang_rad(deg)=1.0650
#  flux(Mx)=4.482e+19, cap_area(cm2)=5.258e+18
#  B0_lead(T)=-8.525e-04, B0_trail(T)=8.525e-04
# Inserting BMR idx= 85 phase= 13.0 month= 13
#  lat=27.00 deg, lon=107.00 deg, tilt=4.78 deg
#  radius(Mm)=20.003, radius_cm=2.000e+09, ang_rad(deg)=1.6467
#  flux(Mx)=1.072e+20, cap_area(cm2)=1.257e+19
#  B0_lead(T)=8.525e-04, B0_trail(T)=-8.525e-04
# Inserting BMR idx= 86 phase= 13.0 month= 13
#  lat=-23.00 deg, lon=79.00 deg, tilt=-4.41 deg
#  radius(Mm)=62.751, radius_cm=6.275e+09, ang_rad(deg)=5.1657
#  flux(Mx)=1.055e+21, cap_area(cm2)=1.236e+20
#  B0_lead(T)=-8.530e-04, B0_trail(T)=8.530e-04
# Inserting BMR idx= 87 phase= 13.0 month= 13
#  lat=29.00 deg, lon=56.00 deg, tilt=4.95 deg
#  radius(Mm)=44.423, radius_cm=4.442e+09, ang_rad(deg)=3.6569
#  flux(Mx)=5.285e+20, cap_area(cm2)=6.197e+19
#  B0_lead(T)=8.527e-04, B0_trail(T)=-8.527e-04
# 14 month(s) start
# Inserting BMR idx= 88 phase= 14.0 month= 14
#  lat=-39.00 deg, lon=172.00 deg, tilt=-5.74 deg
#  radius(Mm)=73.212, radius_cm=7.321e+09, ang_rad(deg)=6.0270
#  flux(Mx)=1.259e+21, cap_area(cm2)=1.682e+20
#  B0_lead(T)=-7.481e-04, B0_trail(T)=7.481e-04
# Inserting BMR idx= 89 phase= 14.0 month= 14
#  lat=27.00 deg, lon=280.00 deg, tilt=4.78 deg
#  radius(Mm)=30.687, radius_cm=3.069e+09, ang_rad(deg)=2.5262
#  flux(Mx)=2.211e+20, cap_area(cm2)=2.958e+19
#  B0_lead(T)=7.476e-04, B0_trail(T)=-7.476e-04
# Inserting BMR idx= 90 phase= 14.0 month= 14
#  lat=-28.00 deg, lon=103.00 deg, tilt=-4.87 deg
#  radius(Mm)=71.095, radius_cm=7.110e+09, ang_rad(deg)=5.8527
#  flux(Mx)=1.187e+21, cap_area(cm2)=1.587e+20
#  B0_lead(T)=-7.481e-04, B0_trail(T)=7.481e-04
# Inserting BMR idx= 91 phase= 14.0 month= 14
#  lat=37.00 deg, lon=249.00 deg, tilt=5.59 deg
#  radius(Mm)=77.760, radius_cm=7.776e+09, ang_rad(deg)=6.4013
#  flux(Mx)=1.420e+21, cap_area(cm2)=1.898e+20
#  B0_lead(T)=7.482e-04, B0_trail(T)=-7.482e-04
# Inserting BMR idx= 92 phase= 14.0 month= 14
#  lat=-25.00 deg, lon=8.00 deg, tilt=-4.60 deg
#  radius(Mm)=17.770, radius_cm=1.777e+09, ang_rad(deg)=1.4629
#  flux(Mx)=7.415e+19, cap_area(cm2)=9.920e+18
#  B0_lead(T)=-7.475e-04, B0_trail(T)=7.475e-04
# 15 month(s) start
# Inserting BMR idx= 93 phase= 15.0 month= 15
#  lat=20.00 deg, lon=10.00 deg, tilt=4.11 deg
#  radius(Mm)=50.021, radius_cm=5.002e+09, ang_rad(deg)=4.1178
#  flux(Mx)=6.429e+20, cap_area(cm2)=7.857e+19
#  B0_lead(T)=8.182e-04, B0_trail(T)=-8.182e-04
# Inserting BMR idx= 94 phase= 15.0 month= 15
#  lat=-42.00 deg, lon=357.00 deg, tilt=-5.96 deg
#  radius(Mm)=19.670, radius_cm=1.967e+09, ang_rad(deg)=1.6192
#  flux(Mx)=9.940e+19, cap_area(cm2)=1.215e+19
#  B0_lead(T)=-8.179e-04, B0_trail(T)=8.179e-04
# Inserting BMR idx= 95 phase= 15.0 month= 15
#  lat=19.00 deg, lon=135.00 deg, tilt=4.01 deg
#  radius(Mm)=60.323, radius_cm=6.032e+09, ang_rad(deg)=4.9658
#  flux(Mx)=9.349e+20, cap_area(cm2)=1.142e+20
#  B0_lead(T)=8.183e-04, B0_trail(T)=-8.183e-04
# Inserting BMR idx= 96 phase= 15.0 month= 15
#  lat=-32.00 deg, lon=66.00 deg, tilt=-5.20 deg
#  radius(Mm)=41.528, radius_cm=4.153e+09, ang_rad(deg)=3.4186
#  flux(Mx)=4.431e+20, cap_area(cm2)=5.416e+19
#  B0_lead(T)=-8.181e-04, B0_trail(T)=8.181e-04
# Inserting BMR idx= 97 phase= 15.0 month= 15
#  lat=32.00 deg, lon=130.00 deg, tilt=5.20 deg
#  radius(Mm)=64.260, radius_cm=6.426e+09, ang_rad(deg)=5.2900
#  flux(Mx)=1.061e+21, cap_area(cm2)=1.296e+20
#  B0_lead(T)=8.184e-04, B0_trail(T)=-8.184e-04
# Inserting BMR idx= 98 phase= 15.0 month= 15
#  lat=-15.00 deg, lon=341.00 deg, tilt=-3.56 deg
#  radius(Mm)=71.078, radius_cm=7.108e+09, ang_rad(deg)=5.8512
#  flux(Mx)=1.298e+21, cap_area(cm2)=1.586e+20
#  B0_lead(T)=-8.185e-04, B0_trail(T)=8.185e-04
# 16 month(s) start
# Inserting BMR idx= 99 phase= 16.0 month= 16
#  lat=15.00 deg, lon=314.00 deg, tilt=3.56 deg
#  radius(Mm)=61.211, radius_cm=6.121e+09, ang_rad(deg)=5.0390
#  flux(Mx)=1.039e+21, cap_area(cm2)=1.176e+20
#  B0_lead(T)=8.834e-04, B0_trail(T)=-8.834e-04
# Inserting BMR idx= 100 phase= 16.0 month= 16
#  lat=-36.00 deg, lon=12.00 deg, tilt=-5.52 deg
#  radius(Mm)=59.439, radius_cm=5.944e+09, ang_rad(deg)=4.8931
#  flux(Mx)=9.798e+20, cap_area(cm2)=1.109e+20
#  B0_lead(T)=-8.833e-04, B0_trail(T)=8.833e-04
# Inserting BMR idx= 101 phase= 16.0 month= 16
#  lat=35.00 deg, lon=286.00 deg, tilt=5.44 deg
#  radius(Mm)=38.758, radius_cm=3.876e+09, ang_rad(deg)=3.1906
#  flux(Mx)=4.166e+20, cap_area(cm2)=4.718e+19
#  B0_lead(T)=8.830e-04, B0_trail(T)=-8.830e-04
# Inserting BMR idx= 102 phase= 16.0 month= 16
#  lat=-23.00 deg, lon=168.00 deg, tilt=-4.41 deg
#  radius(Mm)=67.521, radius_cm=6.752e+09, ang_rad(deg)=5.5584
#  flux(Mx)=1.264e+21, cap_area(cm2)=1.431e+20
#  B0_lead(T)=-8.835e-04, B0_trail(T)=8.835e-04
# Inserting BMR idx= 103 phase= 16.0 month= 16
#  lat=26.00 deg, lon=184.00 deg, tilt=4.69 deg
#  radius(Mm)=66.930, radius_cm=6.693e+09, ang_rad(deg)=5.5098
#  flux(Mx)=1.242e+21, cap_area(cm2)=1.406e+20
#  B0_lead(T)=8.835e-04, B0_trail(T)=-8.835e-04
# Inserting BMR idx= 104 phase= 16.0 month= 16
#  lat=-34.00 deg, lon=258.00 deg, tilt=-5.36 deg
#  radius(Mm)=68.998, radius_cm=6.900e+09, ang_rad(deg)=5.6801
#  flux(Mx)=1.320e+21, cap_area(cm2)=1.494e+20
#  B0_lead(T)=-8.835e-04, B0_trail(T)=8.835e-04
# Inserting BMR idx= 105 phase= 16.0 month= 16
#  lat=34.00 deg, lon=153.00 deg, tilt=5.36 deg
#  radius(Mm)=46.707, radius_cm=4.671e+09, ang_rad(deg)=3.8450
#  flux(Mx)=6.050e+20, cap_area(cm2)=6.851e+19
#  B0_lead(T)=8.831e-04, B0_trail(T)=-8.831e-04
# Inserting BMR idx= 106 phase= 16.0 month= 16
#  lat=-20.00 deg, lon=173.00 deg, tilt=-4.11 deg
#  radius(Mm)=38.091, radius_cm=3.809e+09, ang_rad(deg)=3.1357
#  flux(Mx)=4.024e+20, cap_area(cm2)=4.557e+19
#  B0_lead(T)=-8.830e-04, B0_trail(T)=8.830e-04
# Inserting BMR idx= 107 phase= 16.0 month= 16
#  lat=38.00 deg, lon=73.00 deg, tilt=5.67 deg
#  radius(Mm)=51.097, radius_cm=5.110e+09, ang_rad(deg)=4.2064
#  flux(Mx)=7.241e+20, cap_area(cm2)=8.199e+19
#  B0_lead(T)=8.832e-04, B0_trail(T)=-8.832e-04
# Inserting BMR idx= 108 phase= 16.0 month= 16
#  lat=-34.00 deg, lon=109.00 deg, tilt=-5.36 deg
#  radius(Mm)=40.919, radius_cm=4.092e+09, ang_rad(deg)=3.3685
#  flux(Mx)=4.644e+20, cap_area(cm2)=5.259e+19
#  B0_lead(T)=-8.830e-04, B0_trail(T)=8.830e-04
# 17 month(s) start
# Inserting BMR idx= 109 phase= 17.0 month= 17
#  lat=38.00 deg, lon=171.00 deg, tilt=5.67 deg
#  radius(Mm)=61.540, radius_cm=6.154e+09, ang_rad(deg)=5.0661
#  flux(Mx)=1.066e+21, cap_area(cm2)=1.189e+20
#  B0_lead(T)=8.962e-04, B0_trail(T)=-8.962e-04
# Inserting BMR idx= 110 phase= 17.0 month= 17
#  lat=-17.00 deg, lon=308.00 deg, tilt=-3.79 deg
#  radius(Mm)=61.767, radius_cm=6.177e+09, ang_rad(deg)=5.0848
#  flux(Mx)=1.073e+21, cap_area(cm2)=1.198e+20
#  B0_lead(T)=-8.962e-04, B0_trail(T)=8.962e-04
# Inserting BMR idx= 111 phase= 17.0 month= 17
#  lat=17.00 deg, lon=172.00 deg, tilt=3.79 deg
#  radius(Mm)=29.000, radius_cm=2.900e+09, ang_rad(deg)=2.3873
#  flux(Mx)=2.366e+20, cap_area(cm2)=2.642e+19
#  B0_lead(T)=8.957e-04, B0_trail(T)=-8.957e-04
# Inserting BMR idx= 112 phase= 17.0 month= 17
#  lat=-36.00 deg, lon=142.00 deg, tilt=-5.52 deg
#  radius(Mm)=77.158, radius_cm=7.716e+09, ang_rad(deg)=6.3518
#  flux(Mx)=1.675e+21, cap_area(cm2)=1.868e+20
#  B0_lead(T)=-8.965e-04, B0_trail(T)=8.965e-04
# Inserting BMR idx= 113 phase= 17.0 month= 17
#  lat=32.00 deg, lon=294.00 deg, tilt=5.20 deg
#  radius(Mm)=61.894, radius_cm=6.189e+09, ang_rad(deg)=5.0952
#  flux(Mx)=1.078e+21, cap_area(cm2)=1.203e+20
#  B0_lead(T)=8.962e-04, B0_trail(T)=-8.962e-04
# Inserting BMR idx= 114 phase= 17.0 month= 17
#  lat=-20.00 deg, lon=195.00 deg, tilt=-4.11 deg
#  radius(Mm)=58.065, radius_cm=5.807e+09, ang_rad(deg)=4.7800
#  flux(Mx)=9.486e+20, cap_area(cm2)=1.059e+20
#  B0_lead(T)=-8.961e-04, B0_trail(T)=8.961e-04
# Inserting BMR idx= 115 phase= 17.0 month= 17
#  lat=20.00 deg, lon=35.00 deg, tilt=4.11 deg
#  radius(Mm)=39.785, radius_cm=3.979e+09, ang_rad(deg)=3.2752
#  flux(Mx)=4.453e+20, cap_area(cm2)=4.971e+19
#  B0_lead(T)=8.958e-04, B0_trail(T)=-8.958e-04
# Inserting BMR idx= 116 phase= 17.0 month= 17
#  lat=-17.00 deg, lon=121.00 deg, tilt=-3.79 deg
#  radius(Mm)=38.946, radius_cm=3.895e+09, ang_rad(deg)=3.2061
#  flux(Mx)=4.267e+20, cap_area(cm2)=4.764e+19
#  B0_lead(T)=-8.958e-04, B0_trail(T)=8.958e-04
# Inserting BMR idx= 117 phase= 17.0 month= 17
#  lat=25.00 deg, lon=70.00 deg, tilt=4.60 deg
#  radius(Mm)=69.117, radius_cm=6.912e+09, ang_rad(deg)=5.6898
#  flux(Mx)=1.344e+21, cap_area(cm2)=1.500e+20
#  B0_lead(T)=8.963e-04, B0_trail(T)=-8.963e-04
# Inserting BMR idx= 118 phase= 17.0 month= 17
#  lat=-41.00 deg, lon=337.00 deg, tilt=-5.89 deg
#  radius(Mm)=12.545, radius_cm=1.255e+09, ang_rad(deg)=1.0327
#  flux(Mx)=4.428e+19, cap_area(cm2)=4.944e+18
#  B0_lead(T)=-8.956e-04, B0_trail(T)=8.956e-04
# Inserting BMR idx= 119 phase= 17.0 month= 17
#  lat=41.00 deg, lon=122.00 deg, tilt=5.89 deg
#  radius(Mm)=17.942, radius_cm=1.794e+09, ang_rad(deg)=1.4770
#  flux(Mx)=9.057e+19, cap_area(cm2)=1.011e+19
#  B0_lead(T)=8.956e-04, B0_trail(T)=-8.956e-04
# Inserting BMR idx= 120 phase= 17.0 month= 17
#  lat=-25.00 deg, lon=44.00 deg, tilt=-4.60 deg
#  radius(Mm)=72.314, radius_cm=7.231e+09, ang_rad(deg)=5.9530
#  flux(Mx)=1.471e+21, cap_area(cm2)=1.641e+20
#  B0_lead(T)=-8.964e-04, B0_trail(T)=8.964e-04
# 18 month(s) start
# Inserting BMR idx= 121 phase= 18.0 month= 18
#  lat=22.00 deg, lon=44.00 deg, tilt=4.31 deg
#  radius(Mm)=57.919, radius_cm=5.792e+09, ang_rad(deg)=4.7680
#  flux(Mx)=8.563e+20, cap_area(cm2)=1.053e+20
#  B0_lead(T)=8.130e-04, B0_trail(T)=-8.130e-04
# Inserting BMR idx= 122 phase= 18.0 month= 18
#  lat=-34.00 deg, lon=184.00 deg, tilt=-5.36 deg
#  radius(Mm)=38.843, radius_cm=3.884e+09, ang_rad(deg)=3.1976
#  flux(Mx)=3.851e+20, cap_area(cm2)=4.739e+19
#  B0_lead(T)=-8.127e-04, B0_trail(T)=8.127e-04
# Inserting BMR idx= 123 phase= 18.0 month= 18
#  lat=22.00 deg, lon=28.00 deg, tilt=4.31 deg
#  radius(Mm)=30.137, radius_cm=3.014e+09, ang_rad(deg)=2.4809
#  flux(Mx)=2.318e+20, cap_area(cm2)=2.853e+19
#  B0_lead(T)=8.126e-04, B0_trail(T)=-8.126e-04
# Inserting BMR idx= 124 phase= 18.0 month= 18
#  lat=-36.00 deg, lon=203.00 deg, tilt=-5.52 deg
#  radius(Mm)=70.634, radius_cm=7.063e+09, ang_rad(deg)=5.8147
#  flux(Mx)=1.273e+21, cap_area(cm2)=1.566e+20
#  B0_lead(T)=-8.132e-04, B0_trail(T)=8.132e-04
# Inserting BMR idx= 125 phase= 18.0 month= 18
#  lat=36.00 deg, lon=147.00 deg, tilt=5.52 deg
#  radius(Mm)=27.441, radius_cm=2.744e+09, ang_rad(deg)=2.2590
#  flux(Mx)=1.922e+20, cap_area(cm2)=2.365e+19
#  B0_lead(T)=8.126e-04, B0_trail(T)=-8.126e-04
# Inserting BMR idx= 126 phase= 18.0 month= 18
#  lat=-26.00 deg, lon=309.00 deg, tilt=-4.69 deg
#  radius(Mm)=59.145, radius_cm=5.914e+09, ang_rad(deg)=4.8689
#  flux(Mx)=8.929e+20, cap_area(cm2)=1.098e+20
#  B0_lead(T)=-8.130e-04, B0_trail(T)=8.130e-04
# Inserting BMR idx= 127 phase= 18.0 month= 18
#  lat=22.00 deg, lon=205.00 deg, tilt=4.31 deg
#  radius(Mm)=56.312, radius_cm=5.631e+09, ang_rad(deg)=4.6357
#  flux(Mx)=8.094e+20, cap_area(cm2)=9.957e+19
#  B0_lead(T)=8.129e-04, B0_trail(T)=-8.129e-04
# 19 month(s) start
# Inserting BMR idx= 128 phase= 19.0 month= 19
#  lat=-19.00 deg, lon=351.00 deg, tilt=-4.01 deg
#  radius(Mm)=39.500, radius_cm=3.950e+09, ang_rad(deg)=3.2517
#  flux(Mx)=4.102e+20, cap_area(cm2)=4.900e+19
#  B0_lead(T)=-8.370e-04, B0_trail(T)=8.370e-04
# Inserting BMR idx= 129 phase= 19.0 month= 19
#  lat=14.00 deg, lon=110.00 deg, tilt=3.44 deg
#  radius(Mm)=11.331, radius_cm=1.133e+09, ang_rad(deg)=0.9328
#  flux(Mx)=3.375e+19, cap_area(cm2)=4.034e+18
#  B0_lead(T)=8.368e-04, B0_trail(T)=-8.368e-04
# Inserting BMR idx= 130 phase= 19.0 month= 19
#  lat=-19.00 deg, lon=53.00 deg, tilt=-4.01 deg
#  radius(Mm)=52.922, radius_cm=5.292e+09, ang_rad(deg)=4.3566
#  flux(Mx)=7.363e+20, cap_area(cm2)=8.794e+19
#  B0_lead(T)=-8.372e-04, B0_trail(T)=8.372e-04
# Inserting BMR idx= 131 phase= 19.0 month= 19
#  lat=41.00 deg, lon=310.00 deg, tilt=5.89 deg
#  radius(Mm)=43.754, radius_cm=4.375e+09, ang_rad(deg)=3.6019
#  flux(Mx)=5.033e+20, cap_area(cm2)=6.012e+19
#  B0_lead(T)=8.371e-04, B0_trail(T)=-8.371e-04
# Inserting BMR idx= 132 phase= 19.0 month= 19
#  lat=-20.00 deg, lon=34.00 deg, tilt=-4.11 deg
#  radius(Mm)=32.745, radius_cm=3.275e+09, ang_rad(deg)=2.6956
#  flux(Mx)=2.819e+20, cap_area(cm2)=3.368e+19
#  B0_lead(T)=-8.370e-04, B0_trail(T)=8.370e-04
# Inserting BMR idx= 133 phase= 19.0 month= 19
#  lat=36.00 deg, lon=352.00 deg, tilt=5.52 deg
#  radius(Mm)=18.753, radius_cm=1.875e+09, ang_rad(deg)=1.5437
#  flux(Mx)=9.245e+19, cap_area(cm2)=1.105e+19
#  B0_lead(T)=8.369e-04, B0_trail(T)=-8.369e-04
# Inserting BMR idx= 134 phase= 19.0 month= 19
#  lat=-17.00 deg, lon=276.00 deg, tilt=-3.79 deg
#  radius(Mm)=46.082, radius_cm=4.608e+09, ang_rad(deg)=3.7936
#  flux(Mx)=5.583e+20, cap_area(cm2)=6.669e+19
#  B0_lead(T)=-8.371e-04, B0_trail(T)=8.371e-04
# Inserting BMR idx= 135 phase= 19.0 month= 19
#  lat=25.00 deg, lon=48.00 deg, tilt=4.60 deg
#  radius(Mm)=38.336, radius_cm=3.834e+09, ang_rad(deg)=3.1559
#  flux(Mx)=3.864e+20, cap_area(cm2)=4.616e+19
#  B0_lead(T)=8.370e-04, B0_trail(T)=-8.370e-04
# Inserting BMR idx= 136 phase= 19.0 month= 19
#  lat=-30.00 deg, lon=193.00 deg, tilt=-5.04 deg
#  radius(Mm)=39.777, radius_cm=3.978e+09, ang_rad(deg)=3.2745
#  flux(Mx)=4.160e+20, cap_area(cm2)=4.969e+19
#  B0_lead(T)=-8.370e-04, B0_trail(T)=8.370e-04
# Inserting BMR idx= 137 phase= 19.0 month= 19
#  lat=18.00 deg, lon=346.00 deg, tilt=3.90 deg
#  radius(Mm)=43.756, radius_cm=4.376e+09, ang_rad(deg)=3.6021
#  flux(Mx)=5.033e+20, cap_area(cm2)=6.013e+19
#  B0_lead(T)=8.371e-04, B0_trail(T)=-8.371e-04
# 20 month(s) start
# Inserting BMR idx= 138 phase= 20.0 month= 20
#  lat=-37.00 deg, lon=296.00 deg, tilt=-5.59 deg
#  radius(Mm)=65.349, radius_cm=6.535e+09, ang_rad(deg)=5.3796
#  flux(Mx)=1.068e+21, cap_area(cm2)=1.341e+20
#  B0_lead(T)=-7.963e-04, B0_trail(T)=7.963e-04
# Inserting BMR idx= 139 phase= 20.0 month= 20
#  lat=18.00 deg, lon=173.00 deg, tilt=3.90 deg
#  radius(Mm)=33.340, radius_cm=3.334e+09, ang_rad(deg)=2.7446
#  flux(Mx)=2.779e+20, cap_area(cm2)=3.491e+19
#  B0_lead(T)=7.959e-04, B0_trail(T)=-7.959e-04
# Inserting BMR idx= 140 phase= 20.0 month= 20
#  lat=-41.00 deg, lon=112.00 deg, tilt=-5.89 deg
#  radius(Mm)=69.850, radius_cm=6.985e+09, ang_rad(deg)=5.7502
#  flux(Mx)=1.220e+21, cap_area(cm2)=1.532e+20
#  B0_lead(T)=-7.964e-04, B0_trail(T)=7.964e-04
# Inserting BMR idx= 141 phase= 20.0 month= 20
#  lat=21.00 deg, lon=195.00 deg, tilt=4.21 deg
#  radius(Mm)=13.507, radius_cm=1.351e+09, ang_rad(deg)=1.1119
#  flux(Mx)=4.560e+19, cap_area(cm2)=5.731e+18
#  B0_lead(T)=7.957e-04, B0_trail(T)=-7.957e-04
# Inserting BMR idx= 142 phase= 20.0 month= 20
#  lat=-20.00 deg, lon=319.00 deg, tilt=-4.11 deg
#  radius(Mm)=10.139, radius_cm=1.014e+09, ang_rad(deg)=0.8347
#  flux(Mx)=2.570e+19, cap_area(cm2)=3.230e+18
#  B0_lead(T)=-7.957e-04, B0_trail(T)=7.957e-04
# Inserting BMR idx= 143 phase= 20.0 month= 20
#  lat=16.00 deg, lon=102.00 deg, tilt=3.68 deg
#  radius(Mm)=38.020, radius_cm=3.802e+09, ang_rad(deg)=3.1298
#  flux(Mx)=3.613e+20, cap_area(cm2)=4.540e+19
#  B0_lead(T)=7.959e-04, B0_trail(T)=-7.959e-04
# Inserting BMR idx= 144 phase= 20.0 month= 20
#  lat=-20.00 deg, lon=245.00 deg, tilt=-4.11 deg
#  radius(Mm)=48.986, radius_cm=4.899e+09, ang_rad(deg)=4.0326
#  flux(Mx)=5.999e+20, cap_area(cm2)=7.536e+19
#  B0_lead(T)=-7.960e-04, B0_trail(T)=7.960e-04
# Inserting BMR idx= 145 phase= 20.0 month= 20
#  lat=31.00 deg, lon=94.00 deg, tilt=5.12 deg
#  radius(Mm)=52.652, radius_cm=5.265e+09, ang_rad(deg)=4.3344
#  flux(Mx)=6.930e+20, cap_area(cm2)=8.705e+19
#  B0_lead(T)=7.961e-04, B0_trail(T)=-7.961e-04
# 21 month(s) start
# Inserting BMR idx= 146 phase= 21.0 month= 21
#  lat=-33.00 deg, lon=171.00 deg, tilt=-5.28 deg
#  radius(Mm)=67.540, radius_cm=6.754e+09, ang_rad(deg)=5.5600
#  flux(Mx)=1.306e+21, cap_area(cm2)=1.432e+20
#  B0_lead(T)=-9.123e-04, B0_trail(T)=9.123e-04
# Inserting BMR idx= 147 phase= 21.0 month= 21
#  lat=36.00 deg, lon=227.00 deg, tilt=5.52 deg
#  radius(Mm)=39.989, radius_cm=3.999e+09, ang_rad(deg)=3.2920
#  flux(Mx)=4.580e+20, cap_area(cm2)=5.022e+19
#  B0_lead(T)=9.119e-04, B0_trail(T)=-9.119e-04
# Inserting BMR idx= 148 phase= 21.0 month= 21
#  lat=-33.00 deg, lon=317.00 deg, tilt=-5.28 deg
#  radius(Mm)=35.279, radius_cm=3.528e+09, ang_rad(deg)=2.9042
#  flux(Mx)=3.564e+20, cap_area(cm2)=3.909e+19
#  B0_lead(T)=-9.118e-04, B0_trail(T)=9.118e-04
# Inserting BMR idx= 149 phase= 21.0 month= 21
#  lat=35.00 deg, lon=229.00 deg, tilt=5.44 deg
#  radius(Mm)=39.878, radius_cm=3.988e+09, ang_rad(deg)=3.2828
#  flux(Mx)=4.554e+20, cap_area(cm2)=4.995e+19
#  B0_lead(T)=9.119e-04, B0_trail(T)=-9.119e-04
# Inserting BMR idx= 150 phase= 21.0 month= 21
#  lat=-32.00 deg, lon=220.00 deg, tilt=-5.20 deg
#  radius(Mm)=65.831, radius_cm=6.583e+09, ang_rad(deg)=5.4193
#  flux(Mx)=1.241e+21, cap_area(cm2)=1.360e+20
#  B0_lead(T)=-9.123e-04, B0_trail(T)=9.123e-04
# Inserting BMR idx= 151 phase= 21.0 month= 21
#  lat=31.00 deg, lon=68.00 deg, tilt=5.12 deg
#  radius(Mm)=16.953, radius_cm=1.695e+09, ang_rad(deg)=1.3956
#  flux(Mx)=8.231e+19, cap_area(cm2)=9.029e+18
#  B0_lead(T)=9.117e-04, B0_trail(T)=-9.117e-04
# Inserting BMR idx= 152 phase= 21.0 month= 21
#  lat=-15.00 deg, lon=220.00 deg, tilt=-3.56 deg
#  radius(Mm)=43.900, radius_cm=4.390e+09, ang_rad(deg)=3.6139
#  flux(Mx)=5.519e+20, cap_area(cm2)=6.053e+19
#  B0_lead(T)=-9.119e-04, B0_trail(T)=9.119e-04
# Inserting BMR idx= 153 phase= 21.0 month= 21
#  lat=30.00 deg, lon=177.00 deg, tilt=5.04 deg
#  radius(Mm)=43.321, radius_cm=4.332e+09, ang_rad(deg)=3.5663
#  flux(Mx)=5.375e+20, cap_area(cm2)=5.894e+19
#  B0_lead(T)=9.119e-04, B0_trail(T)=-9.119e-04
# Inserting BMR idx= 154 phase= 21.0 month= 21
#  lat=-20.00 deg, lon=176.00 deg, tilt=-4.11 deg
#  radius(Mm)=43.209, radius_cm=4.321e+09, ang_rad(deg)=3.5571
#  flux(Mx)=5.347e+20, cap_area(cm2)=5.864e+19
#  B0_lead(T)=-9.119e-04, B0_trail(T)=9.119e-04
# Inserting BMR idx= 155 phase= 21.0 month= 21
#  lat=22.00 deg, lon=232.00 deg, tilt=4.31 deg
#  radius(Mm)=49.829, radius_cm=4.983e+09, ang_rad(deg)=4.1020
#  flux(Mx)=7.111e+20, cap_area(cm2)=7.797e+19
#  B0_lead(T)=9.120e-04, B0_trail(T)=-9.120e-04
# Inserting BMR idx= 156 phase= 21.0 month= 21
#  lat=-33.00 deg, lon=272.00 deg, tilt=-5.28 deg
#  radius(Mm)=10.925, radius_cm=1.092e+09, ang_rad(deg)=0.8994
#  flux(Mx)=3.418e+19, cap_area(cm2)=3.750e+18
#  B0_lead(T)=-9.116e-04, B0_trail(T)=9.116e-04
# 22 month(s) start
# Inserting BMR idx= 157 phase= 22.0 month= 22
#  lat=17.00 deg, lon=230.00 deg, tilt=3.79 deg
#  radius(Mm)=15.699, radius_cm=1.570e+09, ang_rad(deg)=1.2924
#  flux(Mx)=7.277e+19, cap_area(cm2)=7.742e+18
#  B0_lead(T)=9.399e-04, B0_trail(T)=-9.399e-04
# Inserting BMR idx= 158 phase= 22.0 month= 22
#  lat=-35.00 deg, lon=57.00 deg, tilt=-5.44 deg
#  radius(Mm)=32.896, radius_cm=3.290e+09, ang_rad(deg)=2.7081
#  flux(Mx)=3.195e+20, cap_area(cm2)=3.399e+19
#  B0_lead(T)=-9.400e-04, B0_trail(T)=9.400e-04
# Inserting BMR idx= 159 phase= 22.0 month= 22
#  lat=28.00 deg, lon=137.00 deg, tilt=4.87 deg
#  radius(Mm)=36.632, radius_cm=3.663e+09, ang_rad(deg)=3.0156
#  flux(Mx)=3.962e+20, cap_area(cm2)=4.215e+19
#  B0_lead(T)=9.401e-04, B0_trail(T)=-9.401e-04
# Inserting BMR idx= 160 phase= 22.0 month= 22
#  lat=-29.00 deg, lon=181.00 deg, tilt=-4.95 deg
#  radius(Mm)=26.896, radius_cm=2.690e+09, ang_rad(deg)=2.2141
#  flux(Mx)=2.136e+20, cap_area(cm2)=2.272e+19
#  B0_lead(T)=-9.400e-04, B0_trail(T)=9.400e-04
# Inserting BMR idx= 161 phase= 22.0 month= 22
#  lat=30.00 deg, lon=331.00 deg, tilt=5.04 deg
#  radius(Mm)=54.527, radius_cm=5.453e+09, ang_rad(deg)=4.4887
#  flux(Mx)=8.779e+20, cap_area(cm2)=9.336e+19
#  B0_lead(T)=9.403e-04, B0_trail(T)=-9.403e-04
# Inserting BMR idx= 162 phase= 22.0 month= 22
#  lat=-23.00 deg, lon=288.00 deg, tilt=-4.41 deg
#  radius(Mm)=76.036, radius_cm=7.604e+09, ang_rad(deg)=6.2594
#  flux(Mx)=1.707e+21, cap_area(cm2)=1.814e+20
#  B0_lead(T)=-9.408e-04, B0_trail(T)=9.408e-04
# Inserting BMR idx= 163 phase= 22.0 month= 22
#  lat=33.00 deg, lon=114.00 deg, tilt=5.28 deg
#  radius(Mm)=23.563, radius_cm=2.356e+09, ang_rad(deg)=1.9397
#  flux(Mx)=1.639e+20, cap_area(cm2)=1.744e+19
#  B0_lead(T)=9.399e-04, B0_trail(T)=-9.399e-04
# Inserting BMR idx= 164 phase= 22.0 month= 22
#  lat=-18.00 deg, lon=274.00 deg, tilt=-3.90 deg
#  radius(Mm)=40.354, radius_cm=4.035e+09, ang_rad(deg)=3.3220
#  flux(Mx)=4.808e+20, cap_area(cm2)=5.115e+19
#  B0_lead(T)=-9.401e-04, B0_trail(T)=9.401e-04
# Inserting BMR idx= 165 phase= 22.0 month= 22
#  lat=18.00 deg, lon=267.00 deg, tilt=3.90 deg
#  radius(Mm)=14.176, radius_cm=1.418e+09, ang_rad(deg)=1.1670
#  flux(Mx)=5.933e+19, cap_area(cm2)=6.313e+18
#  B0_lead(T)=9.399e-04, B0_trail(T)=-9.399e-04
# Inserting BMR idx= 166 phase= 22.0 month= 22
#  lat=-27.00 deg, lon=75.00 deg, tilt=-4.78 deg
#  radius(Mm)=52.776, radius_cm=5.278e+09, ang_rad(deg)=4.3446
#  flux(Mx)=8.224e+20, cap_area(cm2)=8.746e+19
#  B0_lead(T)=-9.403e-04, B0_trail(T)=9.403e-04
# Inserting BMR idx= 167 phase= 22.0 month= 22
#  lat=38.00 deg, lon=79.00 deg, tilt=5.67 deg
#  radius(Mm)=51.436, radius_cm=5.144e+09, ang_rad(deg)=4.2343
#  flux(Mx)=7.812e+20, cap_area(cm2)=8.308e+19
#  B0_lead(T)=9.403e-04, B0_trail(T)=-9.403e-04
# Inserting BMR idx= 168 phase= 22.0 month= 22
#  lat=-36.00 deg, lon=37.00 deg, tilt=-5.52 deg
#  radius(Mm)=70.687, radius_cm=7.069e+09, ang_rad(deg)=5.8190
#  flux(Mx)=1.475e+21, cap_area(cm2)=1.568e+20
#  B0_lead(T)=-9.407e-04, B0_trail(T)=9.407e-04
# Inserting BMR idx= 169 phase= 22.0 month= 22
#  lat=29.00 deg, lon=307.00 deg, tilt=4.95 deg
#  radius(Mm)=71.998, radius_cm=7.200e+09, ang_rad(deg)=5.9270
#  flux(Mx)=1.531e+21, cap_area(cm2)=1.627e+20
#  B0_lead(T)=9.407e-04, B0_trail(T)=-9.407e-04
# Inserting BMR idx= 170 phase= 22.0 month= 22
#  lat=-34.00 deg, lon=312.00 deg, tilt=-5.36 deg
#  radius(Mm)=65.905, radius_cm=6.591e+09, ang_rad(deg)=5.4254
#  flux(Mx)=1.282e+21, cap_area(cm2)=1.364e+20
#  B0_lead(T)=-9.406e-04, B0_trail(T)=9.406e-04
# Inserting BMR idx= 171 phase= 22.0 month= 22
#  lat=22.00 deg, lon=112.00 deg, tilt=4.31 deg
#  radius(Mm)=67.068, radius_cm=6.707e+09, ang_rad(deg)=5.5211
#  flux(Mx)=1.328e+21, cap_area(cm2)=1.412e+20
#  B0_lead(T)=9.406e-04, B0_trail(T)=-9.406e-04
# 23 month(s) start
# Inserting BMR idx= 172 phase= 23.0 month= 23
#  lat=-17.00 deg, lon=118.00 deg, tilt=-3.79 deg
#  radius(Mm)=13.660, radius_cm=1.366e+09, ang_rad(deg)=1.1245
#  flux(Mx)=5.241e+19, cap_area(cm2)=5.862e+18
#  B0_lead(T)=-8.940e-04, B0_trail(T)=8.940e-04
# Inserting BMR idx= 173 phase= 23.0 month= 23
#  lat=28.00 deg, lon=336.00 deg, tilt=4.87 deg
#  radius(Mm)=65.681, radius_cm=6.568e+09, ang_rad(deg)=5.4070
#  flux(Mx)=1.212e+21, cap_area(cm2)=1.354e+20
#  B0_lead(T)=8.946e-04, B0_trail(T)=-8.946e-04
# Inserting BMR idx= 174 phase= 23.0 month= 23
#  lat=-22.00 deg, lon=87.00 deg, tilt=-4.31 deg
#  radius(Mm)=16.023, radius_cm=1.602e+09, ang_rad(deg)=1.3190
#  flux(Mx)=7.210e+19, cap_area(cm2)=8.065e+18
#  B0_lead(T)=-8.940e-04, B0_trail(T)=8.940e-04
# Inserting BMR idx= 175 phase= 23.0 month= 23
#  lat=30.00 deg, lon=131.00 deg, tilt=5.04 deg
#  radius(Mm)=20.006, radius_cm=2.001e+09, ang_rad(deg)=1.6469
#  flux(Mx)=1.124e+20, cap_area(cm2)=1.257e+19
#  B0_lead(T)=8.940e-04, B0_trail(T)=-8.940e-04
# Inserting BMR idx= 176 phase= 23.0 month= 23
#  lat=-28.00 deg, lon=131.00 deg, tilt=-4.87 deg
#  radius(Mm)=38.460, radius_cm=3.846e+09, ang_rad(deg)=3.1661
#  flux(Mx)=4.154e+20, cap_area(cm2)=4.646e+19
#  B0_lead(T)=-8.942e-04, B0_trail(T)=8.942e-04
# Inserting BMR idx= 177 phase= 23.0 month= 23
#  lat=26.00 deg, lon=312.00 deg, tilt=4.69 deg
#  radius(Mm)=25.090, radius_cm=2.509e+09, ang_rad(deg)=2.0654
#  flux(Mx)=1.768e+20, cap_area(cm2)=1.977e+19
#  B0_lead(T)=8.941e-04, B0_trail(T)=-8.941e-04
# Inserting BMR idx= 178 phase= 23.0 month= 23
#  lat=-21.00 deg, lon=208.00 deg, tilt=-4.21 deg
#  radius(Mm)=15.424, radius_cm=1.542e+09, ang_rad(deg)=1.2697
#  flux(Mx)=6.681e+19, cap_area(cm2)=7.474e+18
#  B0_lead(T)=-8.940e-04, B0_trail(T)=8.940e-04
# Inserting BMR idx= 179 phase= 23.0 month= 23
#  lat=24.00 deg, lon=172.00 deg, tilt=4.50 deg
#  radius(Mm)=31.744, radius_cm=3.174e+09, ang_rad(deg)=2.6132
#  flux(Mx)=2.830e+20, cap_area(cm2)=3.165e+19
#  B0_lead(T)=8.941e-04, B0_trail(T)=-8.941e-04
# Inserting BMR idx= 180 phase= 23.0 month= 23
#  lat=-25.00 deg, lon=56.00 deg, tilt=-4.60 deg
#  radius(Mm)=64.213, radius_cm=6.421e+09, ang_rad(deg)=5.2861
#  flux(Mx)=1.158e+21, cap_area(cm2)=1.294e+20
#  B0_lead(T)=-8.946e-04, B0_trail(T)=8.946e-04
# Inserting BMR idx= 181 phase= 23.0 month= 23
#  lat=26.00 deg, lon=149.00 deg, tilt=4.69 deg
#  radius(Mm)=52.612, radius_cm=5.261e+09, ang_rad(deg)=4.3311
#  flux(Mx)=7.774e+20, cap_area(cm2)=8.692e+19
#  B0_lead(T)=8.944e-04, B0_trail(T)=-8.944e-04
# Inserting BMR idx= 182 phase= 23.0 month= 23
#  lat=-27.00 deg, lon=56.00 deg, tilt=-4.78 deg
#  radius(Mm)=26.206, radius_cm=2.621e+09, ang_rad(deg)=2.1573
#  flux(Mx)=1.929e+20, cap_area(cm2)=2.157e+19
#  B0_lead(T)=-8.941e-04, B0_trail(T)=8.941e-04
# Inserting BMR idx= 183 phase= 23.0 month= 23
#  lat=24.00 deg, lon=113.00 deg, tilt=4.50 deg
#  radius(Mm)=77.937, radius_cm=7.794e+09, ang_rad(deg)=6.4159
#  flux(Mx)=1.706e+21, cap_area(cm2)=1.906e+20
#  B0_lead(T)=8.949e-04, B0_trail(T)=-8.949e-04
# Inserting BMR idx= 184 phase= 23.0 month= 23
#  lat=-21.00 deg, lon=274.00 deg, tilt=-4.21 deg
#  radius(Mm)=48.813, radius_cm=4.881e+09, ang_rad(deg)=4.0183
#  flux(Mx)=6.692e+20, cap_area(cm2)=7.482e+19
#  B0_lead(T)=-8.943e-04, B0_trail(T)=8.943e-04
# Inserting BMR idx= 185 phase= 23.0 month= 23
#  lat=16.00 deg, lon=17.00 deg, tilt=3.68 deg
#  radius(Mm)=72.018, radius_cm=7.202e+09, ang_rad(deg)=5.9286
#  flux(Mx)=1.457e+21, cap_area(cm2)=1.628e+20
#  B0_lead(T)=8.948e-04, B0_trail(T)=-8.948e-04
# 24 month(s) start
# Inserting BMR idx= 186 phase= 24.0 month= 24
#  lat=-24.00 deg, lon=290.00 deg, tilt=-4.50 deg
#  radius(Mm)=49.391, radius_cm=4.939e+09, ang_rad(deg)=4.0659
#  flux(Mx)=7.764e+20, cap_area(cm2)=7.661e+19
#  B0_lead(T)=-1.014e-03, B0_trail(T)=1.014e-03
# Inserting BMR idx= 187 phase= 24.0 month= 24
#  lat=21.00 deg, lon=267.00 deg, tilt=4.21 deg
#  radius(Mm)=63.251, radius_cm=6.325e+09, ang_rad(deg)=5.2069
#  flux(Mx)=1.273e+21, cap_area(cm2)=1.256e+20
#  B0_lead(T)=1.014e-03, B0_trail(T)=-1.014e-03
# Inserting BMR idx= 188 phase= 24.0 month= 24
#  lat=-32.00 deg, lon=95.00 deg, tilt=-5.20 deg
#  radius(Mm)=54.466, radius_cm=5.447e+09, ang_rad(deg)=4.4837
#  flux(Mx)=9.442e+20, cap_area(cm2)=9.315e+19
#  B0_lead(T)=-1.014e-03, B0_trail(T)=1.014e-03
# Inserting BMR idx= 189 phase= 24.0 month= 24
#  lat=32.00 deg, lon=232.00 deg, tilt=5.20 deg
#  radius(Mm)=25.474, radius_cm=2.547e+09, ang_rad(deg)=2.0970
#  flux(Mx)=2.065e+20, cap_area(cm2)=2.038e+19
#  B0_lead(T)=1.013e-03, B0_trail(T)=-1.013e-03
# Inserting BMR idx= 190 phase= 24.0 month= 24
#  lat=-28.00 deg, lon=183.00 deg, tilt=-4.87 deg
#  radius(Mm)=25.704, radius_cm=2.570e+09, ang_rad(deg)=2.1160
#  flux(Mx)=2.103e+20, cap_area(cm2)=2.075e+19
#  B0_lead(T)=-1.013e-03, B0_trail(T)=1.013e-03
# Inserting BMR idx= 191 phase= 24.0 month= 24
#  lat=34.00 deg, lon=87.00 deg, tilt=5.36 deg
#  radius(Mm)=39.173, radius_cm=3.917e+09, ang_rad(deg)=3.2248
#  flux(Mx)=4.884e+20, cap_area(cm2)=4.820e+19
#  B0_lead(T)=1.013e-03, B0_trail(T)=-1.013e-03
# Inserting BMR idx= 192 phase= 24.0 month= 24
#  lat=-34.00 deg, lon=297.00 deg, tilt=-5.36 deg
#  radius(Mm)=44.961, radius_cm=4.496e+09, ang_rad(deg)=3.7012
#  flux(Mx)=6.434e+20, cap_area(cm2)=6.348e+19
#  B0_lead(T)=-1.013e-03, B0_trail(T)=1.013e-03
# Inserting BMR idx= 193 phase= 24.0 month= 24
#  lat=40.00 deg, lon=56.00 deg, tilt=5.82 deg
#  radius(Mm)=17.263, radius_cm=1.726e+09, ang_rad(deg)=1.4211
#  flux(Mx)=9.484e+19, cap_area(cm2)=9.361e+18
#  B0_lead(T)=1.013e-03, B0_trail(T)=-1.013e-03
# Inserting BMR idx= 194 phase= 24.0 month= 24
#  lat=-26.00 deg, lon=180.00 deg, tilt=-4.69 deg
#  radius(Mm)=62.097, radius_cm=6.210e+09, ang_rad(deg)=5.1119
#  flux(Mx)=1.227e+21, cap_area(cm2)=1.211e+20
#  B0_lead(T)=-1.014e-03, B0_trail(T)=1.014e-03
# Inserting BMR idx= 195 phase= 24.0 month= 24
#  lat=40.00 deg, lon=109.00 deg, tilt=5.82 deg
#  radius(Mm)=40.774, radius_cm=4.077e+09, ang_rad(deg)=3.3566
#  flux(Mx)=5.291e+20, cap_area(cm2)=5.222e+19
#  B0_lead(T)=1.013e-03, B0_trail(T)=-1.013e-03
# ...
#  radius(Mm)=66.179, radius_cm=6.618e+09, ang_rad(deg)=5.4479
#  flux(Mx)=1.282e+21, cap_area(cm2)=1.375e+20
#  B0_lead(T)=-9.324e-04, B0_trail(T)=9.324e-04
# Inserting BMR idx= 2781 phase= 128.0 month= 128
#  lat=6.00 deg, lon=350.00 deg, tilt=2.25 deg
#  radius(Mm)=45.586, radius_cm=4.559e+09, ang_rad(deg)=3.7527
#  flux(Mx)=6.083e+20, cap_area(cm2)=6.526e+19
#  B0_lead(T)=9.321e-04, B0_trail(T)=-9.321e-04
# Inserting BMR idx= 2782 phase= 128.0 month= 128
#  lat=-5.00 deg, lon=277.00 deg, tilt=-2.06 deg
#  radius(Mm)=31.426, radius_cm=3.143e+09, ang_rad(deg)=2.5870
#  flux(Mx)=2.891e+20, cap_area(cm2)=3.102e+19
#  B0_lead(T)=-9.319e-04, B0_trail(T)=9.319e-04
# Inserting BMR idx= 2783 phase= 128.0 month= 128
#  lat=10.00 deg, lon=282.00 deg, tilt=2.91 deg
#  radius(Mm)=34.485, radius_cm=3.448e+09, ang_rad(deg)=2.8388
#  flux(Mx)=3.481e+20, cap_area(cm2)=3.735e+19
#  B0_lead(T)=9.319e-04, B0_trail(T)=-9.319e-04
# Inserting BMR idx= 2784 phase= 128.0 month= 128
#  lat=-9.00 deg, lon=60.00 deg, tilt=-2.76 deg
#  radius(Mm)=67.336, radius_cm=6.734e+09, ang_rad(deg)=5.5432
#  flux(Mx)=1.327e+21, cap_area(cm2)=1.423e+20
#  B0_lead(T)=-9.325e-04, B0_trail(T)=9.325e-04
# Inserting BMR idx= 2785 phase= 128.0 month= 128
#  lat=16.00 deg, lon=4.00 deg, tilt=3.68 deg
#  radius(Mm)=35.910, radius_cm=3.591e+09, ang_rad(deg)=2.9562
#  flux(Mx)=3.775e+20, cap_area(cm2)=4.050e+19
#  B0_lead(T)=9.319e-04, B0_trail(T)=-9.319e-04
# Inserting BMR idx= 2786 phase= 128.0 month= 128
#  lat=8.00 deg, lon=40.00 deg, tilt=2.60 deg
#  radius(Mm)=21.337, radius_cm=2.134e+09, ang_rad(deg)=1.7565
#  flux(Mx)=1.333e+20, cap_area(cm2)=1.430e+19
#  B0_lead(T)=9.318e-04, B0_trail(T)=-9.318e-04
# Inserting BMR idx= 2787 phase= 128.0 month= 128
#  lat=-14.00 deg, lon=186.00 deg, tilt=-3.44 deg
#  radius(Mm)=77.025, radius_cm=7.703e+09, ang_rad(deg)=6.3408
#  flux(Mx)=1.737e+21, cap_area(cm2)=1.862e+20
#  B0_lead(T)=-9.327e-04, B0_trail(T)=9.327e-04
# 129 month(s) start
# Inserting BMR idx= 2788 phase= 129.0 month= 129
#  lat=11.00 deg, lon=322.00 deg, tilt=3.05 deg
#  radius(Mm)=59.649, radius_cm=5.965e+09, ang_rad(deg)=4.9104
#  flux(Mx)=1.002e+21, cap_area(cm2)=1.117e+20
#  B0_lead(T)=8.969e-04, B0_trail(T)=-8.969e-04
# Inserting BMR idx= 2789 phase= 129.0 month= 129
#  lat=-9.00 deg, lon=199.00 deg, tilt=-2.76 deg
#  radius(Mm)=68.023, radius_cm=6.802e+09, ang_rad(deg)=5.5997
#  flux(Mx)=1.303e+21, cap_area(cm2)=1.452e+20
#  B0_lead(T)=-8.971e-04, B0_trail(T)=8.971e-04
# Inserting BMR idx= 2790 phase= 129.0 month= 129
#  lat=4.00 deg, lon=64.00 deg, tilt=1.84 deg
#  radius(Mm)=27.487, radius_cm=2.749e+09, ang_rad(deg)=2.2628
#  flux(Mx)=2.128e+20, cap_area(cm2)=2.373e+19
#  B0_lead(T)=8.965e-04, B0_trail(T)=-8.965e-04
# Inserting BMR idx= 2791 phase= 129.0 month= 129
#  lat=-6.00 deg, lon=127.00 deg, tilt=-2.25 deg
#  radius(Mm)=60.741, radius_cm=6.074e+09, ang_rad(deg)=5.0003
#  flux(Mx)=1.039e+21, cap_area(cm2)=1.158e+20
#  B0_lead(T)=-8.970e-04, B0_trail(T)=8.970e-04
# Inserting BMR idx= 2792 phase= 129.0 month= 129
#  lat=12.00 deg, lon=356.00 deg, tilt=3.19 deg
#  radius(Mm)=69.507, radius_cm=6.951e+09, ang_rad(deg)=5.7219
#  flux(Mx)=1.361e+21, cap_area(cm2)=1.516e+20
#  B0_lead(T)=8.971e-04, B0_trail(T)=-8.971e-04
# Inserting BMR idx= 2793 phase= 129.0 month= 129
#  lat=-15.00 deg, lon=31.00 deg, tilt=-3.56 deg
#  radius(Mm)=49.068, radius_cm=4.907e+09, ang_rad(deg)=4.0393
#  flux(Mx)=6.780e+20, cap_area(cm2)=7.561e+19
#  B0_lead(T)=-8.968e-04, B0_trail(T)=8.968e-04
# Inserting BMR idx= 2794 phase= 129.0 month= 129
#  lat=4.00 deg, lon=257.00 deg, tilt=1.84 deg
#  radius(Mm)=18.436, radius_cm=1.844e+09, ang_rad(deg)=1.5177
#  flux(Mx)=9.572e+19, cap_area(cm2)=1.068e+19
#  B0_lead(T)=8.964e-04, B0_trail(T)=-8.964e-04
# Inserting BMR idx= 2795 phase= 129.0 month= 129
#  lat=-2.00 deg, lon=276.00 deg, tilt=-1.30 deg
#  radius(Mm)=50.610, radius_cm=5.061e+09, ang_rad(deg)=4.1663
#  flux(Mx)=7.213e+20, cap_area(cm2)=8.043e+19
#  B0_lead(T)=-8.968e-04, B0_trail(T)=8.968e-04
# Inserting BMR idx= 2796 phase= 129.0 month= 129
#  lat=4.00 deg, lon=182.00 deg, tilt=1.84 deg
#  radius(Mm)=47.904, radius_cm=4.790e+09, ang_rad(deg)=3.9435
#  flux(Mx)=6.462e+20, cap_area(cm2)=7.207e+19
#  B0_lead(T)=8.967e-04, B0_trail(T)=-8.967e-04
# Inserting BMR idx= 2797 phase= 129.0 month= 129
#  lat=-6.00 deg, lon=80.00 deg, tilt=-2.25 deg
#  radius(Mm)=66.645, radius_cm=6.664e+09, ang_rad(deg)=5.4863
#  flux(Mx)=1.251e+21, cap_area(cm2)=1.394e+20
#  B0_lead(T)=-8.971e-04, B0_trail(T)=8.971e-04
# 130 month(s) start
# Inserting BMR idx= 2798 phase= 130.0 month= 130
#  lat=12.00 deg, lon=178.00 deg, tilt=3.19 deg
#  radius(Mm)=38.829, radius_cm=3.883e+09, ang_rad(deg)=3.1964
#  flux(Mx)=4.358e+20, cap_area(cm2)=4.735e+19
#  B0_lead(T)=9.202e-04, B0_trail(T)=-9.202e-04
# Inserting BMR idx= 2799 phase= 130.0 month= 130
#  lat=-6.00 deg, lon=37.00 deg, tilt=-2.25 deg
#  radius(Mm)=66.055, radius_cm=6.605e+09, ang_rad(deg)=5.4377
#  flux(Mx)=1.261e+21, cap_area(cm2)=1.370e+20
#  B0_lead(T)=-9.207e-04, B0_trail(T)=9.207e-04
# Inserting BMR idx= 2800 phase= 130.0 month= 130
#  lat=8.00 deg, lon=174.00 deg, tilt=2.60 deg
#  radius(Mm)=59.274, radius_cm=5.927e+09, ang_rad(deg)=4.8795
#  flux(Mx)=1.015e+21, cap_area(cm2)=1.103e+20
#  B0_lead(T)=9.205e-04, B0_trail(T)=-9.205e-04
# Inserting BMR idx= 2801 phase= 130.0 month= 130
#  lat=-15.00 deg, lon=294.00 deg, tilt=-3.56 deg
#  radius(Mm)=55.805, radius_cm=5.581e+09, ang_rad(deg)=4.5940
#  flux(Mx)=9.001e+20, cap_area(cm2)=9.778e+19
#  B0_lead(T)=-9.205e-04, B0_trail(T)=9.205e-04
# Inserting BMR idx= 2802 phase= 130.0 month= 130
#  lat=12.00 deg, lon=33.00 deg, tilt=3.19 deg
#  radius(Mm)=69.510, radius_cm=6.951e+09, ang_rad(deg)=5.7222
#  flux(Mx)=1.396e+21, cap_area(cm2)=1.517e+20
#  B0_lead(T)=9.207e-04, B0_trail(T)=-9.207e-04
# Inserting BMR idx= 2803 phase= 130.0 month= 130
#  lat=-8.00 deg, lon=274.00 deg, tilt=-2.60 deg
#  radius(Mm)=33.908, radius_cm=3.391e+09, ang_rad(deg)=2.7914
#  flux(Mx)=3.323e+20, cap_area(cm2)=3.611e+19
#  B0_lead(T)=-9.202e-04, B0_trail(T)=9.202e-04
# Inserting BMR idx= 2804 phase= 130.0 month= 130
#  lat=2.00 deg, lon=21.00 deg, tilt=1.30 deg
#  radius(Mm)=32.133, radius_cm=3.213e+09, ang_rad(deg)=2.6453
#  flux(Mx)=2.984e+20, cap_area(cm2)=3.243e+19
#  B0_lead(T)=9.201e-04, B0_trail(T)=-9.201e-04
# Inserting BMR idx= 2805 phase= 130.0 month= 130
#  lat=-11.00 deg, lon=103.00 deg, tilt=-3.05 deg
#  radius(Mm)=22.888, radius_cm=2.289e+09, ang_rad(deg)=1.8841
#  flux(Mx)=1.514e+20, cap_area(cm2)=1.646e+19
#  B0_lead(T)=-9.201e-04, B0_trail(T)=9.201e-04
# Inserting BMR idx= 2806 phase= 130.0 month= 130
#  lat=11.00 deg, lon=250.00 deg, tilt=3.05 deg
#  radius(Mm)=33.590, radius_cm=3.359e+09, ang_rad(deg)=2.7652
#  flux(Mx)=3.261e+20, cap_area(cm2)=3.544e+19
#  B0_lead(T)=9.202e-04, B0_trail(T)=-9.202e-04
# Inserting BMR idx= 2807 phase= 130.0 month= 130
#  lat=-4.00 deg, lon=346.00 deg, tilt=-1.84 deg
#  radius(Mm)=71.265, radius_cm=7.126e+09, ang_rad(deg)=5.8666
#  flux(Mx)=1.468e+21, cap_area(cm2)=1.594e+20
#  B0_lead(T)=-9.208e-04, B0_trail(T)=9.208e-04
# Inserting BMR idx= 2808 phase= 130.0 month= 130
#  lat=3.00 deg, lon=272.00 deg, tilt=1.59 deg
#  radius(Mm)=56.502, radius_cm=5.650e+09, ang_rad(deg)=4.6513
#  flux(Mx)=9.227e+20, cap_area(cm2)=1.002e+20
#  B0_lead(T)=9.205e-04, B0_trail(T)=-9.205e-04
# 131 month(s) start
# Inserting BMR idx= 2809 phase= 131.0 month= 131
#  lat=-5.00 deg, lon=279.00 deg, tilt=-2.06 deg
#  radius(Mm)=14.267, radius_cm=1.427e+09, ang_rad(deg)=1.1745
#  flux(Mx)=6.283e+19, cap_area(cm2)=6.394e+18
#  B0_lead(T)=-9.826e-04, B0_trail(T)=9.826e-04
# Inserting BMR idx= 2810 phase= 131.0 month= 131
#  lat=12.00 deg, lon=261.00 deg, tilt=3.19 deg
#  radius(Mm)=39.386, radius_cm=3.939e+09, ang_rad(deg)=3.2423
#  flux(Mx)=4.789e+20, cap_area(cm2)=4.872e+19
#  B0_lead(T)=9.829e-04, B0_trail(T)=-9.829e-04
# Inserting BMR idx= 2811 phase= 131.0 month= 131
#  lat=-9.00 deg, lon=97.00 deg, tilt=-2.76 deg
#  radius(Mm)=50.822, radius_cm=5.082e+09, ang_rad(deg)=4.1838
#  flux(Mx)=7.973e+20, cap_area(cm2)=8.111e+19
#  B0_lead(T)=-9.830e-04, B0_trail(T)=9.830e-04
# Inserting BMR idx= 2812 phase= 131.0 month= 131
#  lat=8.00 deg, lon=119.00 deg, tilt=2.60 deg
#  radius(Mm)=43.489, radius_cm=4.349e+09, ang_rad(deg)=3.5801
#  flux(Mx)=5.838e+20, cap_area(cm2)=5.940e+19
#  B0_lead(T)=9.829e-04, B0_trail(T)=-9.829e-04
# Inserting BMR idx= 2813 phase= 131.0 month= 131
#  lat=-9.00 deg, lon=106.00 deg, tilt=-2.76 deg
#  radius(Mm)=56.655, radius_cm=5.666e+09, ang_rad(deg)=4.6639
#  flux(Mx)=9.908e+20, cap_area(cm2)=1.008e+20
#  B0_lead(T)=-9.831e-04, B0_trail(T)=9.831e-04
# Inserting BMR idx= 2814 phase= 131.0 month= 131
#  lat=4.00 deg, lon=354.00 deg, tilt=1.84 deg
#  radius(Mm)=75.371, radius_cm=7.537e+09, ang_rad(deg)=6.2046
#  flux(Mx)=1.754e+21, cap_area(cm2)=1.783e+20
#  B0_lead(T)=9.836e-04, B0_trail(T)=-9.836e-04
# Inserting BMR idx= 2815 phase= 131.0 month= 131
#  lat=-11.00 deg, lon=111.00 deg, tilt=-3.05 deg
#  radius(Mm)=43.403, radius_cm=4.340e+09, ang_rad(deg)=3.5730
#  flux(Mx)=5.815e+20, cap_area(cm2)=5.916e+19
#  B0_lead(T)=-9.829e-04, B0_trail(T)=9.829e-04
# Inserting BMR idx= 2816 phase= 131.0 month= 131
#  lat=10.00 deg, lon=224.00 deg, tilt=2.91 deg
#  radius(Mm)=15.208, radius_cm=1.521e+09, ang_rad(deg)=1.2520
#  flux(Mx)=7.140e+19, cap_area(cm2)=7.266e+18
#  B0_lead(T)=9.826e-04, B0_trail(T)=-9.826e-04
# Inserting BMR idx= 2817 phase= 131.0 month= 131
#  lat=-4.00 deg, lon=22.00 deg, tilt=-1.84 deg
#  radius(Mm)=44.426, radius_cm=4.443e+09, ang_rad(deg)=3.6572
#  flux(Mx)=6.093e+20, cap_area(cm2)=6.198e+19
#  B0_lead(T)=-9.829e-04, B0_trail(T)=9.829e-04
# Inserting BMR idx= 2818 phase= 131.0 month= 131
#  lat=13.00 deg, lon=22.00 deg, tilt=3.32 deg
#  radius(Mm)=59.914, radius_cm=5.991e+09, ang_rad(deg)=4.9322
#  flux(Mx)=1.108e+21, cap_area(cm2)=1.127e+20
#  B0_lead(T)=9.832e-04, B0_trail(T)=-9.832e-04
# Inserting BMR idx= 2819 phase= 131.0 month= 131
#  lat=-14.00 deg, lon=260.00 deg, tilt=-3.44 deg
#  radius(Mm)=41.962, radius_cm=4.196e+09, ang_rad(deg)=3.4544
#  flux(Mx)=5.435e+20, cap_area(cm2)=5.530e+19
#  B0_lead(T)=-9.829e-04, B0_trail(T)=9.829e-04
# Inserting BMR idx= 2820 phase= 131.0 month= 131
#  lat=10.00 deg, lon=65.00 deg, tilt=2.91 deg
#  radius(Mm)=11.655, radius_cm=1.165e+09, ang_rad(deg)=0.9594
#  flux(Mx)=4.193e+19, cap_area(cm2)=4.267e+18
#  B0_lead(T)=9.826e-04, B0_trail(T)=-9.826e-04
# Inserting BMR idx= 2821 phase= 131.0 month= 131
#  lat=-11.00 deg, lon=283.00 deg, tilt=-3.05 deg
#  radius(Mm)=27.965, radius_cm=2.797e+09, ang_rad(deg)=2.3022
#  flux(Mx)=2.414e+20, cap_area(cm2)=2.457e+19
#  B0_lead(T)=-9.827e-04, B0_trail(T)=9.827e-04
# Inserting BMR idx= 2822 phase= 131.0 month= 131
#  lat=4.00 deg, lon=255.00 deg, tilt=1.84 deg
#  radius(Mm)=46.405, radius_cm=4.641e+09, ang_rad(deg)=3.8201
#  flux(Mx)=6.647e+20, cap_area(cm2)=6.763e+19
#  B0_lead(T)=9.830e-04, B0_trail(T)=-9.830e-04
# Inserting BMR idx= 2823 phase= 131.0 month= 131
#  lat=-2.00 deg, lon=254.00 deg, tilt=-1.30 deg
#  radius(Mm)=69.326, radius_cm=6.933e+09, ang_rad(deg)=5.7071
#  flux(Mx)=1.484e+21, cap_area(cm2)=1.509e+20
#  B0_lead(T)=-9.834e-04, B0_trail(T)=9.834e-04
# 132 month(s) start
# Inserting BMR idx= 2824 phase= 132.0 month= 132
#  lat=8.00 deg, lon=138.00 deg, tilt=2.60 deg
#  radius(Mm)=27.914, radius_cm=2.791e+09, ang_rad(deg)=2.2979
#  flux(Mx)=2.293e+20, cap_area(cm2)=2.448e+19
#  B0_lead(T)=9.370e-04, B0_trail(T)=-9.370e-04
# Inserting BMR idx= 2825 phase= 132.0 month= 132
#  lat=-7.00 deg, lon=356.00 deg, tilt=-2.43 deg
#  radius(Mm)=25.196, radius_cm=2.520e+09, ang_rad(deg)=2.0742
#  flux(Mx)=1.868e+20, cap_area(cm2)=1.994e+19
#  B0_lead(T)=-9.369e-04, B0_trail(T)=9.369e-04
# Inserting BMR idx= 2826 phase= 132.0 month= 132
#  lat=11.00 deg, lon=165.00 deg, tilt=3.05 deg
#  radius(Mm)=53.988, radius_cm=5.399e+09, ang_rad(deg)=4.4444
#  flux(Mx)=8.578e+20, cap_area(cm2)=9.152e+19
#  B0_lead(T)=9.373e-04, B0_trail(T)=-9.373e-04
# Inserting BMR idx= 2827 phase= 132.0 month= 132
#  lat=-13.00 deg, lon=301.00 deg, tilt=-3.32 deg
#  radius(Mm)=44.291, radius_cm=4.429e+09, ang_rad(deg)=3.6461
#  flux(Mx)=5.774e+20, cap_area(cm2)=6.161e+19
#  B0_lead(T)=-9.371e-04, B0_trail(T)=9.371e-04
# Inserting BMR idx= 2828 phase= 132.0 month= 132
#  lat=7.00 deg, lon=61.00 deg, tilt=2.43 deg
#  radius(Mm)=33.629, radius_cm=3.363e+09, ang_rad(deg)=2.7684
#  flux(Mx)=3.328e+20, cap_area(cm2)=3.552e+19
#  B0_lead(T)=9.370e-04, B0_trail(T)=-9.370e-04
# Inserting BMR idx= 2829 phase= 132.0 month= 132
#  lat=-5.00 deg, lon=6.00 deg, tilt=-2.06 deg
#  radius(Mm)=32.826, radius_cm=3.283e+09, ang_rad(deg)=2.7023
#  flux(Mx)=3.171e+20, cap_area(cm2)=3.385e+19
#  B0_lead(T)=-9.370e-04, B0_trail(T)=9.370e-04
# Inserting BMR idx= 2830 phase= 132.0 month= 132
#  lat=14.00 deg, lon=9.00 deg, tilt=3.44 deg
#  radius(Mm)=53.372, radius_cm=5.337e+09, ang_rad(deg)=4.3937
#  flux(Mx)=8.384e+20, cap_area(cm2)=8.945e+19
#  B0_lead(T)=9.373e-04, B0_trail(T)=-9.373e-04
# Inserting BMR idx= 2831 phase= 132.0 month= 132
#  lat=-5.00 deg, lon=159.00 deg, tilt=-2.06 deg
#  radius(Mm)=53.699, radius_cm=5.370e+09, ang_rad(deg)=4.4206
#  flux(Mx)=8.487e+20, cap_area(cm2)=9.055e+19
#  B0_lead(T)=-9.373e-04, B0_trail(T)=9.373e-04
# Inserting BMR idx= 2832 phase= 132.0 month= 132
#  lat=4.00 deg, lon=91.00 deg, tilt=1.84 deg
#  radius(Mm)=17.067, radius_cm=1.707e+09, ang_rad(deg)=1.4050
#  flux(Mx)=8.573e+19, cap_area(cm2)=9.150e+18
#  B0_lead(T)=9.369e-04, B0_trail(T)=-9.369e-04
# Inserting BMR idx= 2833 phase= 132.0 month= 132
#  lat=-12.00 deg, lon=232.00 deg, tilt=-3.19 deg
#  radius(Mm)=64.830, radius_cm=6.483e+09, ang_rad(deg)=5.3369
#  flux(Mx)=1.237e+21, cap_area(cm2)=1.319e+20
#  B0_lead(T)=-9.375e-04, B0_trail(T)=9.375e-04
# Inserting BMR idx= 2834 phase= 132.0 month= 132
#  lat=14.00 deg, lon=125.00 deg, tilt=3.44 deg
#  radius(Mm)=66.286, radius_cm=6.629e+09, ang_rad(deg)=5.4568
#  flux(Mx)=1.293e+21, cap_area(cm2)=1.379e+20
#  B0_lead(T)=9.375e-04, B0_trail(T)=-9.375e-04
# Inserting BMR idx= 2835 phase= 132.0 month= 132
#  lat=-13.00 deg, lon=325.00 deg, tilt=-3.32 deg
#  radius(Mm)=30.066, radius_cm=3.007e+09, ang_rad(deg)=2.4751
#  flux(Mx)=2.661e+20, cap_area(cm2)=2.840e+19
#  B0_lead(T)=-9.370e-04, B0_trail(T)=9.370e-04
# Inserting BMR idx= 2836 phase= 132.0 month= 132
#  lat=9.00 deg, lon=61.00 deg, tilt=2.76 deg
#  radius(Mm)=74.480, radius_cm=7.448e+09, ang_rad(deg)=6.1313
#  flux(Mx)=1.633e+21, cap_area(cm2)=1.741e+20
#  B0_lead(T)=9.377e-04, B0_trail(T)=-9.377e-04
# 133 month(s) start
# Inserting BMR idx= 2837 phase= 133.0 month= 133
#  lat=-9.00 deg, lon=280.00 deg, tilt=-2.76 deg
#  radius(Mm)=63.108, radius_cm=6.311e+09, ang_rad(deg)=5.1951
#  flux(Mx)=1.070e+21, cap_area(cm2)=1.250e+20
#  B0_lead(T)=-8.556e-04, B0_trail(T)=8.556e-04
# Inserting BMR idx= 2838 phase= 133.0 month= 133
#  lat=8.00 deg, lon=93.00 deg, tilt=2.60 deg
#  radius(Mm)=26.804, radius_cm=2.680e+09, ang_rad(deg)=2.2066
#  flux(Mx)=1.930e+20, cap_area(cm2)=2.257e+19
#  B0_lead(T)=8.551e-04, B0_trail(T)=-8.551e-04
# Inserting BMR idx= 2839 phase= 133.0 month= 133
#  lat=-3.00 deg, lon=291.00 deg, tilt=-1.59 deg
#  radius(Mm)=59.841, radius_cm=5.984e+09, ang_rad(deg)=4.9262
#  flux(Mx)=9.619e+20, cap_area(cm2)=1.124e+20
#  B0_lead(T)=-8.555e-04, B0_trail(T)=8.555e-04
# Inserting BMR idx= 2840 phase= 133.0 month= 133
#  lat=9.00 deg, lon=9.00 deg, tilt=2.76 deg
#  radius(Mm)=67.545, radius_cm=6.754e+09, ang_rad(deg)=5.5604
#  flux(Mx)=1.225e+21, cap_area(cm2)=1.432e+20
#  B0_lead(T)=8.557e-04, B0_trail(T)=-8.557e-04
# Inserting BMR idx= 2841 phase= 133.0 month= 133
#  lat=-12.00 deg, lon=103.00 deg, tilt=-3.19 deg
#  radius(Mm)=41.405, radius_cm=4.140e+09, ang_rad(deg)=3.4085
#  flux(Mx)=4.605e+20, cap_area(cm2)=5.384e+19
#  B0_lead(T)=-8.552e-04, B0_trail(T)=8.552e-04
# Inserting BMR idx= 2842 phase= 133.0 month= 133
#  lat=10.00 deg, lon=241.00 deg, tilt=2.91 deg
#  radius(Mm)=26.280, radius_cm=2.628e+09, ang_rad(deg)=2.1634
#  flux(Mx)=1.855e+20, cap_area(cm2)=2.169e+19
#  B0_lead(T)=8.551e-04, B0_trail(T)=-8.551e-04
# Inserting BMR idx= 2843 phase= 133.0 month= 133
#  lat=-13.00 deg, lon=185.00 deg, tilt=-3.32 deg
#  radius(Mm)=70.887, radius_cm=7.089e+09, ang_rad(deg)=5.8356
#  flux(Mx)=1.350e+21, cap_area(cm2)=1.577e+20
#  B0_lead(T)=-8.557e-04, B0_trail(T)=8.557e-04
# Inserting BMR idx= 2844 phase= 133.0 month= 133
#  lat=4.00 deg, lon=317.00 deg, tilt=1.84 deg
#  radius(Mm)=13.699, radius_cm=1.370e+09, ang_rad(deg)=1.1277
#  flux(Mx)=5.040e+19, cap_area(cm2)=5.895e+18
#  B0_lead(T)=8.550e-04, B0_trail(T)=-8.550e-04

# %%
import matplotlib as mpl
mpl.rcParams['animation.embed_limit'] = 50

# %%
all_values = np.transpose(all_values,(0,2,1))

# %%
from matplotlib.animation import FuncAnimation
fig, ax = plt.subplots()
#vmin = np.min(all_values)
#vmax = np.max(all_values)
cax = ax.imshow(all_values[0], extent=[0, 360, 90, -90], aspect='equal', origin='lower', cmap='seismic', vmin=-1e-3, vmax=1e-3)
fig.colorbar(cax, label='Magnetic field strength (Tesla)')
ax.set_title('2D Magnetic Field')
ax.set_ylabel('θ (degrees)')
ax.set_xlabel('φ (degrees)')
ax.set_xticks(np.arange(0, 361, 30))
ax.set_yticks(np.arange(90, -91, -15))
ax.grid(True)
ax.invert_yaxis()

def animate(frame):
    data = all_values[frame]
    ax.set_title(f'Magnetic field of a sunspot at t = {frame*dt*100/365:.2f} years')
    cax.set_data(data)
    return [cax]

ani = FuncAnimation(fig, animate, frames=range(0, all_values.shape[0], 100), interval=1000, blit=True, repeat=False)

plt.close(fig)
from IPython.display import HTML
HTML(ani.to_jshtml())

# %%
from matplotlib.animation import PillowWriter
writer = PillowWriter(fps=2)
ani.save('sunspot_evolution_11_years_1.gif', writer=writer)

# %%
plt.figure(figsize=(7,4))

plt.plot(time_days, flux_north, label="North polar flux")
plt.plot(time_days, flux_south, label="South polar flux")
plt.plot(time_days, flux_total, label="Total Flux")
plt.axhline(0.0, color='k', lw=0.5)
plt.xlabel("Time (days)")
plt.ylabel("Polar Flux (Wb)")
plt.title("Polar Flux Evolution (±25° caps)")
plt.legend()
plt.grid()
plt.tight_layout()
plt.show()
